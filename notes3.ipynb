# %%
import nltk
from nltk import pos_tag, word_tokenize

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# tagging PoS in inputted text
text = word_tokenize("Be careful with that butter knife.")
nltk.pos_tag(text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [('Be', 'VB'),
#  ('careful', 'JJ'),
#  ('with', 'IN'),
#  ('that', 'DT'),
#  ('butter', 'NN'),
#  ('knife', 'NN'),
#  ('.', '.')]

# %%
import nltk

# tokenization is the process of splitting strings into their individual "tokens"
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

# to import a .txt file we use the "open" function, giving it the path to our text file and an instrution about what we want to do with the file
# here, we would like to "read" our file into a variable so 
transcript = open('gismapping.txt', encoding='utf-8').read().lower()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# we could then tokenize by sentence, which splits the text into sentences
transcript_sentences = sent_tokenize(transcript)
transcript_sentences
# Out:
# ['367\narcheologia e calcolatori\n30, 2019, 367-385\ngis mapping of the archaeological sites\nin the molise region (italy)\n1. introduction\nthe molise region is in the northern sector of southern italy and it is\nspread from the apennine chain to the adriatic coast.',
#  'this area experienced\nhuman presence since prehistoric times, as it is testified by its rich archaeological\nand architectural heritage (de benedittis 1979; coarelli, la regina 1984)1\n.',
#  'the oldest human presence in molise is represented by the upper palaeolithic settlement of isernia la pineta, dated back at about 600.000 years\nbp (coltorti et al.',
#  '1982, 2005 and references; peretto 2013).',
#  'the site\nrepresents a unique example in the history of the human frequentation in\neurope for the presence of a considerable number of paleontological finds\nassociated to lithic artefacts.',
#  'other more recent and relevant prehistoric sites\nhave been also found in the municipalities of pescopennataro (rio verde site),\ncarovilli (piana s. mauro and fonte curello sites), rocchetta a volturno\n(grotta reali site), civitanova del sannio (morricone del pesco site), cerro\nal volturno (monte s. croce site) and in the biferno valley (barker 1995;\ngrimaldi 2005; minelli, peretto 2006; rufo et al.',
#  '2010; rufo 2011).',
#  'after prehistoric times, the most relevant archaeological findings can\nbe chronologically dated to the samnite age (ranging from the v to the i\ncentury bc).',
#  'in this period, several villages and about thirty samnite fortifications were built, the latter being in correspondence to some of the highest\ntopographic peaks of the molise region.',
#  'these fortifications were built with\nthe technique of opera poligonalis and were connected to each other through\ntranshumance routes, the so called tratturi (aa.vv.',
#  '1980; pellicano 2007;\nmeini, di felice, petrella 2018; minotti et al.',
#  '2018).',
#  'the remains of\npietrabbondante (fig.',
#  '1 a) (capini, de benedittis 2000; la regina 2014),\nthe small temples of vastogirardi (morel 1984; pagano, ceccarelli,\nd’andrea 2005) and s. giovanni in galdo (stek 2010), the fortifications\nof terravecchia di sepino (matteini chiari, gaggiotti, de benedettis\n1984) and monte vairano (de benedittis 1974, 1988, 2004) are amazing\nexamples of the samnites’ culture.',
#  'the samnite age ceased with the arrive of the romans, who dominated\nthe entire region in the period between the i century bc and the v century ad.',
#  '1 for this kind of study, the bibliographic research just took into account the most relevant\nand general papers and volumes published for each archaeological site, without considering the\nlarge amount of papers regarding local and specific investigations.',
#  '368\ne. valente, m. cozzolino\nroman findings are evenly widespread in molise, and the city of saepinum (fig.',
#  '1 b) is considered the symbol of the history of roman civilization.',
#  'saepinum\nwas a samnite commercial forum and service centre, then it became a roman\nmunicipium and, later, it was transformed into a medieval and modern rural village (gaggiotti, matteini chiari 1979; de benedittis 1981; ceglia 2015).',
#  'other examples of important roman towns are aesernia (fig.',
#  '1 c) (catalano,\npaone, terzani 2001; terzani 2005; stek et al.',
#  '2015; amato et al.',
#  '2016),\nvenafrum (capini 1990; conventi 2004; mataluna 2012), bovianum (de\nbenedittis 1977; amato et al.',
#  '2013 and references) and larinum (de tata\n1990; di niro 1991; caliò, lepone, lippolis 2011; lippolis et al.',
#  '2015).',
#  'medieval findings include, among all, the monastery of san vincenzo\nal volturno (fig.',
#  '1 d) (marazzi, delogu 1996; paone et al.',
#  '2004) and the\nnecropolis of campochiaro (ceglia 1988, 2000 and references; ceglia,\nmarchetta 2012), both testifying the early medieval phase.',
#  'the cathedrals\nof trivento, guardialfiera, termoli and larino and the castles of civitacampomarano, roccamandolfi, cerro al volturno, termoli, venafro, gambatesa\nand campobasso are also noteworthy evidences of medieval age, whose\nstories and transformations represent important pages of the molise history\n(marino, carnevale, pesino 2003; di rocco 2009).',
#  'in the last years, both the superintendency for the archaeological heritage of the molise region and different national and international academic\nteams carried out numerous archaeological excavations and explorations in\nthe entire molise region.',
#  'as a result, some archaeological contexts can now\nrely on a rich literature and updated results, whereas other areas still require\na detailed overall analysis and, especially, a systematic study.',
#  'moreover, many\narchaeological materials derived from emergency excavations during either\npublic or private works are unstudied.',
#  'in addition, there is a lack of an organic\nand complete “reading” of all the known data and the concrete need to acquire\nadditional information on areas that have never been investigated to date.',
#  'in order to standardize and store the myriad of archaeological data from the\nmolise region, from 2013 until present, a fruitful collaboration between the\nuniversity of molise, the regional directorate of cultural heritage of molise\nand the administrative division of molise has led to undertake significant\nactions of intervention for the knowledge and the preservation of the ancient\nlandscape, according to the following workflow:\n– census of all known archaeological findings of the molise region through\nbibliographic analysis.',
#  '– implementation, for the first time, of a detailed and updated archaeological\ndatabase.',
#  '– integration of this database into a geographical information system by\nusing the software arcmap 10.1 to apply spatial analysis techniques and to\nderive thematic maps.',
#  '369\ngis mapping of the archaeological sites in the molise region (italy)\nfig.',
#  '1 – some of the most relevant archaeological sites in the molise region.',
#  'a) remains of pietrabbondante; b) the roman town of sepinum; c) roman walls of aesernia; d) monastery of san\nvincenzo al volturno.',
#  '– generation of an updated computerized map of the archaeological evidences\nof the study area as a product useful for the promotion of the archaeological\nheritage and a tool for more suitable urban planning and project designs.',
#  '2. material and methods\nthe work has been based on separate phases of investigation that include\nthe collection of archaeological data, the collection of topographic data, the\ngis database creation, and the gis spatial analysis.',
#  '2.1 collection of archaeological data\nthe collection of a large amount of data about archaeological sites within\nthe molise region has been carried out through a two steps research.',
#  'in a first\nphase of investigation, published detail scale archaeological researches carried\nout by both local public authorities and single scientists have been analysed.',
#  'the archaeological maps realized in the municipalities of venafro (quilici,\n370\ne. valente, m. cozzolino\nquilici gigli 2011), riccia, oratino, castropignano (de benedittis 2008),\nbonefro, casacalenda, castellino del biferno, colletorto, montelongo, montorio\ndei frentani, morrone del sannio, provvidenti, ripabottoni, rotello, s. croce\ndi magliano, s. giuliano di puglia, ururi (di niro, santone, santoro 2010),\nisernia (stek et al.',
#  '2015; amato et al.',
#  '2016), belmonte del sannio, agnone,\ncapracotta, vastogirardi, san pietro avellana (sardella 2011) and trivento\n(santorelli 2013) are good examples of exhaustive known data related to\ndetail scale archaeological surveys.',
#  'the monographs of the hill-forts of the samnites (oakley 1995) and of the palaeolithic sites in molise (grimaldi 2005)\ngave also important overviews on the distribution of archaeological sites during\nspecific time span.',
#  'the atlas of cultural emergencies of molise (zilli 2010),\nedited by university of molise, has been also analysed; the latter represents,\nup to now, the unique attempt to take a census of archaeological sites in the\nmolise region, resulting in the collection of 228 sites (124 classical sites, 73\nindustrial archaeological remnants, 31 sites belonging to various categories).',
#  'the combination of all the previously mentioned researches led us to\ngather, in 2015, an unprecedented collection of archaeological data in the\nframe of the project “conoscere per competere” supported by the administrative division of molise.',
#  'this project resulted in the collection of 905\narchaeological sites in the entire region.',
#  'in addition, 977 archaeological data\ncollected by barker (1995) in the biferno valley have been also added to our\ndatabase.',
#  'as a result, 1882 archaeological sites have been collected during\nthis first step of the research.',
#  'in a second phase of investigation, the archives of the archaeological\nsuperintendence have been analysed thanks to the collaboration with the\nregional directorate of cultural heritage of molise.',
#  'consequently, new and\ninedited data from archaeological impact assessment reports (related to public or private works) and database regarding excavations, finds, monuments\nand historical buildings have been acquired.',
#  'the combination of these two\nconsecutive phases of investigation led us to collect 3111 archaeological sites\nwithin the entire molise region.',
#  '2.2 collection of topographic data\nthe collection of topographic data includes topographic maps both at\nscale 1:5000 (technical map of the molise region) and 1:25.000 (i.g.m.',
#  'topographic maps) made available by the technical offices of the molise region.',
#  'in addition, a 40 m dtm of the molise region has been used.',
#  '2.3 gis database creation\nall the collected archaeological sites have been listed in a point shapefile through the software arcgis 10.1 and then plotted on the previously\n371\ngis mapping of the archaeological sites in the molise region (italy)\nmentioned topographic maps and on the 40 m molise dtm.',
#  'the point\nshapefile, named “archaeological sites”, includes several fields that have been\nintroduced to provide a complete and accurate description of every single site.',
#  'moreover, fields have been named as follows (field type is in parentheses):\n– code (string, length 10) that includes three letters derived from the name of\nthe municipality where the site is located followed by a progressive number;\n– province (string, length 20), which is the administrative province (either\nisernia or campobasso) where archaeological sites fall within;\n– municipality (string, length 50), the name of the municipality where the\nsite is located;\n– locality (string, length 50) and address (string, length 50), that provide\nfurther information about site location;\n– reference system (string, length 20), that is the reference system used to\ngeolocate archaeological sites (utm-wgs84);\n– z coord (double, precision 0, scale 0), that is the elevation above sea level\nof every site;\n– point x (double, precision 0, scale 0) and point y (double, precision 0, scale\n0) that represent longitude and latitude of the plotted sites respectively;\n– cartography (string, length 20) that is the type of topographic map used to locate the archaeological site (either 1:5000 or 1:25.000 scale topographic maps);\n– number cart.',
#  '(string, length 20) that is the number of the used topographic\nmap;\n– georeferencing method (string, length 50), a brief description of the method used to locate every archaeological site, either by web research, satellite\nimages, topographic maps, field work or aerial photos;\n– georeference quality (string, length 20), which includes three possibilities,\napproximate, good and certain, based on how much reliable the site location is;\n– research method (string, length 50), the research method used to recognize\nevery single site, including web research, bibliographic research and field work;\n– description (string, length 254), a first, brief description of the archaeological\nsites, which have been subdivided in 19 classes;\n– definition (string, length 254) a brief, more detailed description of the sites;\n– description_1 to description_5 (string, length 254), five fields used to\nprovide a very complete and detailed description of every archaeological site;\n– age_1 (string, length 254), a precise age of every site;\n– age_2 (string, length 254), ages grouped in the 11 age ranges proposed by\nbarker (1995): palaeolithic (older than 4500 bc), neolithic (4500 bc-3000\nbc), eneolithic (3000 bc-2000 bc), bronze age (2000 bc-1000 bc), iron age\n(1000 bc-500 bc), samnite age (500 bc-80 bc), roman age (80 bc-600\nbc), medieval age (600 ad-1500 ad), post-medieval age (1500 ad-1800\nad), recent age (1800 ad-present).',
#  '372\ne. valente, m. cozzolino\n– references (string, length 254), both paper and web references where every\nsingle archaeological site has been derived from.',
#  '2.4 gis spatial analysis\nall the 3111 listed archaeological sites have been then analysed in a gis\nsoftware to derive information about their spatial distribution.',
#  'moreover, in\norder to quantify the areal distribution of the mapped sites, we performed a\ndensity analysis trough the “kernel density” method of arcgis 10.1 by setting\nthe following parameters (unit measure is m): output cell size = 284 (which\nis the default value); search radius = 1000; area units = square kilometres;\noutput values as = densities; method = planar.',
#  'then, site distribution during different ages has been analysed by grouping all the archaeological sites in the age classes listed in the age_2 field of\nthe “archaeological site” shapefile.',
#  'archaeological sites grouped for age have\nbeen then plotted on the 40 m molise dtm.',
#  'furthermore, site elevation (expressed in meters above sea level) respect\nthe site age has been examined to verify a possible trend in sites distribution\nthrough time.',
#  'in this case, we have selected all archaeological sites with the\nsame age and exported them in a new point shapefile.',
#  'we have then created a\nbox-plot graph through the “create graph” option within the table of attribute,\nusing site elevation as the value field.',
#  'finally, the archaeological sites spatial distribution and its relationship\nwith some natural (rivers) and man-made (tratturi) features of the landscape\nhas been investigated.',
#  'we created two polyline shapefiles for both the features\nand we applied a buffer of 1000 m to both the “river” and the “tratturi”\nshapefile.',
#  'we have then clipped the “archaeological site” shapefile with this\nbuffer and we have extracted all the sites located within 1000 m from both\nthe river and the tratturi features.',
#  '3. results\nthe spatial distribution of all the 3111 mapped archaeological sites of\nthe molise region is reported in fig.',
#  '2. moreover, archaeological sites have\nbeen plotted on a 40 m dtm of the molise region together with a polyline\nshapefile that includes the borders of all the municipalities of the molise region.',
#  'sites distribution enhances the occurrence of three main clusters located,\nrespectively, in the north-eastern, central and south-western sectors of the\nregion.',
#  'the north-eastern cluster is ne-sw oriented and corresponds with\nthe biferno river valley, being located between the municipalities of petrella\ntifernina and lucito, to the sw, and termoli and campomarino to the ne.',
#  'the central cluster is roughly n-s oriented, being limited by the municipality\nof castropignano and torella del sannio to the n and of bojano, san polo\n373\ngis mapping of the archaeological sites in the molise region (italy)\nmatese and campochiaro to the s. the sw cluster is ne-sw oriented and it\nis limited by the town of isernia to the ne and the municipality of venafro\nto the sw.\namong the entire molise region, the larino municipality has the\nlargest number of archaeological sites within its territory, with 277 mapped\nsites (fig.',
#  '3a).',
#  'it is followed by casacalenda (186 sites, fig.',
#  '3b), isernia (167\nsites, fig.',
#  '4a), guglionesi (162 sites, fig.',
#  '4b), trivento (106 sites, fig.',
#  '5a) and\ncampomarino (102 sites, fig.',
#  '5b), that are the only municipalities with more\nthan 100 archaeological sites.',
#  'other municipalities with a relevant number of archaeological sites are\nvenafro (98 sites), agnone (66 sites), termoli (65 sites), castropignano (61\nsites), baranello (53 sites), macchia valfortore (49 sites), colle d’anchise\nand guardialfiera (46 sites), vinchiaturo (44 sites), morrone del sannio (43\nsites), san martino in pensilis (38 sites), petrella tifernina (36 sites), colli al\nvolturno and oratino (35 sites), and bojano and pietrabbondante (30 sites).',
#  'the remaining municipalities have a few archaeological sites never exceeding\n30. it is worthy to note that campobasso, that is the administrative centre of\nthe molise region and the most populated town of the entire region (49320\ninhabitants), is characterized by the occurrence of only 6 archaeological sites.',
#  'fig.',
#  '2 – spatial distribution of the mapped archaeological sites, plotted on a 40 m\ndtm of the molise region.',
#  'black dots indicate the archaeological sites whereas\nblack lines indicate the borders of all the municipalities of the molise region.',
#  '374\ne. valente, m. cozzolino\nfig.',
#  '3 – map of the archaeological sites for all the municipalities\nwith more than 100 mapped sites.',
#  'a = larino; b = casacalenda.',
#  'archaeological sites have been classified according to site typology\nof the “description” field of the “archaeological site” shapefiles (see\nmaterial and methods section for detail).',
#  'the kernel density method allows us to quantify the number of archaeological sites for square-kilometre (fig.',
#  '6).',
#  'the analysis confirms the\noccurrence of the above described three main clusters with the highest density\nvalue occurring around isernia, where a value of about 82 sites/km² has been\nobtained.',
#  'in addition, maximum site density values of 21 sites/km² and 12\nsites/km² have been obtained, respectively, for the ne-sw trending cluster\n(that corresponds to the biferno river valley) and for the n-s trending cluster\nlocated in the central sector of the molise region.',
#  'furthermore, the analysis\n375\ngis mapping of the archaeological sites in the molise region (italy)\nfig.',
#  '4 – map of the archaeological sites for all the municipalities with\nmore than 100 mapped sites.',
#  'a = isernia; b = guglionesi.',
#  'archaeological sites have been classified according to site typology of the\n“description” field of the “archaeological site” shapefiles (see material\nand methods section for detail).',
#  'enhances the occurrence of other local high-density values.',
#  'the latter are in\nthe central-northern and in the eastern sectors of the molise region, corresponding to the municipalities of trivento and macchia valfortore respectively.',
#  'moreover, a value of 50 sites/km² has been obtained for the trivento cluster\nwhereas a value of about 15 sites/km² has been obtained for the macchia\nvalfortore cluster.',
#  'in figs.',
#  '7a to 7l the chronological distribution of the mapped archaeological sites is reported.',
#  'it is worth to note that 1679 archaeological sites\n376\ne. valente, m. cozzolino\nfig.',
#  '5 – map of the archaeological sites for all the municipalities with more\nthan 100 mapped sites.',
#  'a = trivento; b = campomarino.',
#  'archaeological\nsites have been classified according to site typology of the “description”\nfield of the “archaeological site” shapefiles (see material and methods\nsection for detail).',
#  '(54% of the total) have been either occupied for long time or re-occupied\nafter a period of abandonment, so they will appear in more than one map.',
#  'during the palaeolithic (fig.',
#  '7a) archaeological sites were mainly located in\nthe north-eastern (e.g., the lower biferno river valley) and in the south-western\n(e.g.',
#  'the volturno river valley and the venafro plain) sectors of the molise\nregion, with sparse sporadic sites in the central portion of the region.',
#  '377\ngis mapping of the archaeological sites in the molise region (italy)\nfig.',
#  '6 – density map of the archaeological sites of the molise region.',
#  'the same areas resulted to be occupied also during the neolithic, together\nwith diffuse findings in the central portion of the molise region and in the\nmedium biferno river valley (fig.',
#  '7b).',
#  'during the eneolithic (fig.',
#  '7c), the bronze\nage (fig.',
#  '7d) and the iron age (fig.',
#  '7e), archaeological sites have been recognized only in the biferno river valley and in the central portion of the region.',
#  'on the opposite, they were completely lacking in the western portion of the\nregion, with the only exception of few sporadic findings and of a sites cluster\nin the northern sector of the study area during the iron age.',
#  'archaeological\nsites of samnite age (fig.',
#  '7f) are widespread all over the entire study area, with\nonly some areas in the central portion of the region with some samnite finds.',
#  'the same occurred during the roman time (fig.',
#  '7g), with roman finds\ndistributed in the entire region and mirroring the three main clusters recognized\nin fig.',
#  '1. medieval finds are spread in the entire study area, with two main clusters in the biferno river valley and in the central portion of the region (fig.',
#  '7h).',
#  'on the opposite, post-medieval archaeological sites have been recognized only\nin the biferno valley and in the central portion of the region, being completely\nlacking in the rest of the region (fig.',
#  '7i).',
#  'recent archaeological finds (fig.',
#  '7j)\nare very few with a random distribution within the study area.',
#  'finally, 372 sites\n(12% of the total, fig.',
#  '7k) have an uncertain age and they have been mainly\nrecognized in the central-western portion of the molise region.',
#  '378\ne. valente, m. cozzolino\nfig.',
#  '7 – chronological distribution of the archaeological sites in the molise region.',
#  'white dots\nindicates archaeological sites of a precise age whereas black dots indicate archaeological sites older\nthan the considered age.',
#  'we have also analysed site distribution as a function of the site elevation (expressed in meters above sea level) to verify if either sites distribution\nmoved towards higher or lower elevations during time or if any correlation\nis present.',
#  'in fig.',
#  '8 we report a box plot of the site elevation as a function of\nthe site age.',
#  'it is possible to note that the minimum site elevation is almost\nconstant during different period.',
#  'the median values (dotted line within each\nbox plot of fig.',
#  '8) highlight the occurrence of an increasing trend from the\n379\ngis mapping of the archaeological sites in the molise region (italy)\npalaeolithic (median value around 190 m a.s.l.)',
#  'to the medieval time (median\nvalue around 530 m a.s.l.',
#  '), with a local minimum during the eneolithic age\n(median value around 190 m a.s.l.).',
#  'a decreasing trend of the site elevation has\nbeen recognized from the medieval to the recent ages (median value around\n400 m a.s.l.).',
#  'the same trend has been recognized for the maximum elevations\nwith values ranging from about 1050 m a.s.l.',
#  '(during both the paleolithic and\nthe neolithic ages) to about 1300 m a.s.l.',
#  '(during the medieval age), with a\nlocal minimum during the eneolithic age (maximum elevation around 880\nm a.s.l.)',
#  'and a local maximum during the samnite age (maximum elevation\nclose to 1400 m a.s.l.).',
#  'the typology of archaeological finds is shown in fig.',
#  '9. type groups are\nthose included in the “description” field of the “archaeological site” shapefiles\ndescribed in the material and methods section.',
#  'moreover, the most diffuse\nsite type is the archaeological finds group that includes 57,1% of the total\nmapped sites followed by settlements (12,9%) and buildings (9,8%).',
#  'sacred\nareas represent 5,8% of the total sites whereas buildings dealing with industrial\narchaeology and funeral areas correspond to 2,6% of the total.',
#  'surrounding walls include 2,4% of the total sites, being followed by castles (1,9%),\nfortifications (1,4%) and hydraulic structures (1,3%).',
#  'streets and towers are\nless diffuse, both representing 0,6% of the total mapped areas.',
#  'moreover,\nthe “other” type group includes archaeological sites of distinct types (such\nas caves, cave paintings, submarine archaeological finds and thermal baths)\nthat, collectively, do not exceed 1% of the total mapped sites.',
#  'finally, we have analysed a possible correlation between site location\nand some either man-made (tratturi) or natural (river) features of the landscape (fig.',
#  '10).',
#  'archaeological sites located within 1000 m from the tratturi are reported in fig.',
#  '10a.',
#  'as tratturi appeared during the v century bc\n(mastronardi 2004), the archaeological sites from the palaeolithic to the\niron age have been excluded from this analysis.',
#  'this buffer includes 530\nsites (19% of the 2786 sites ranging in age from the samnite to the recent\ntime), also counting 58 sites of uncertain age.',
#  'all the site typologies listed in\nfig.',
#  '9 fall within this buffer.',
#  'in addition, archaeological sites located within\n1000 m from main rivers are reported in fig.',
#  '10b.',
#  'it includes 399 sites (13%\nof the total) whose ages range from the palaeolithic to the recent time, also\nincluding 45 sites of uncertain age.',
#  'again, all the site typologies listed in\nfig.',
#  '9 fall within this buffer.',
#  '4. discussion and conclusion\nthe use of gis software and database has become widespread practice\nin international archaeology allowing to store and to analyse a large amount\nof data (djindjian 1998; gillings, wheatley 2003; chapman 2006).',
#  '380\ne. valente, m. cozzolino\nfig.',
#  '9 – percentage of archaeological site typology respect to the total\nmapped sites.',
#  'fig.',
#  '8 – box plot of the site elevation (m a.s.l.)',
#  'as a\nfunction of site age.',
#  'moreover, this study provides a powerful tool to analyse human distribution\nin the molise region.',
#  'it represents, up to now, the largest, more detailed and\nwell-organized gis database of archaeological finds within the study area.',
#  'some relevant features could be derived by the gis analysis described in\nthe previous sections.',
#  'first, 3111 archaeological sites represent an unexpected\nand relevant number of mapped sites, widespread in the entire region, with\nthree main clusters located along the biferno river valley, in the central and\nin the south-western sectors of the region, respectively.',
#  'moreover, the highest\ndensities (expressed as site/km²) have been found in the south-western cluster.',
#  'here, the density value of 82 archaeological sites/km² has been recognized in\n381\ngis mapping of the archaeological sites in the molise region (italy)\ncorrespondence of the historical centre of isernia.',
#  'this high-density value is\ndue to the detailed archaeological survey carried out by amato et al.',
#  '(2016)\nthat has been included in our database.',
#  'most of the mapped archaeological\nsites have been classified as archaeological finds, whereas the most diffuse\nsite typologies, that reflect the occurrence of a well-organized human society,\nare settlements, buildings and sacred areas.',
#  'the chronological and the elevation (expressed as meter above sea level)\ndistribution of archaeological sites enhance that, during the palaeolithic to\nthe iron age time span, archaeological sites were clustered along the biferno\nvalley and in the central sector of the molise region.',
#  'in addition, they were\nlocated at the median elevation usually not exceeding 400 m a.s.l.',
#  'probably\nbecause these areas were very close to the river network that represented the\nmain water source at that time.',
#  'during the samnite and roman ages, archaeological sites are almost homogeneously distributed in the entire region.',
#  'in this\nperiod, and during the samnite age, humans started moving uphill, as it is\ntestified by the occurrence of several samnite fortification located on top of\nmany ridges.',
#  'this is due to the necessity to protect human settlements from\nforeign invasion also considering that the highest topographic peaks led the\nview to reach far distances.',
#  'this tendency to protect human settlements is still\npresent during medieval time, when foreign attacks were common.',
#  'for these\nreasons, many castles were built on the top of the ridges during medieval to\npost-medieval times.',
#  'it must be highlighted that the archaeological sites gis database could be\ncontinuously upgraded with the inclusion of new data related to the collection\nof new and unknown archaeological sites.',
#  'it is worthy to note that, anyway,\nfig.',
#  '10 – a) white dots indicate archaeological sites located within 1000 m from the “tratturi”\n(black, continuous line); b) white dots indicate archaeological sites located within 1000 m from\nthe main rivers.',
#  'in both figures, black dots indicate archaeological sites far more than 1000 m from\nthe applied buffers.',
#  '382\ne. valente, m. cozzolino\nthe documentary research has pointed out some critical aspects.',
#  'during the\nanalysis of the superintendence for archaeological heritage archives, it was\nimpossible to trace the complete documentation related either to archaeological surveys carried out during the period 1970-1990 or to excavations in\ncourse of publication.',
#  'in addition, there is an anomalous lack of information\non some archaeological contexts, as evidenced by the few archaeological sites\nmapped in the municipality of campobasso.',
#  'furthermore, archaeological sites\nare missing in other areas because of the lack of interest of the scientific community to carry on a systematic study.',
#  'in other cases, the geomorphological\nand the environmental features of the territory were not favourable to the\nestablishment of human settlements.',
#  'notwithstanding the limits of data collection, the product of this research\nrepresents an exhaustive census of archaeological sites within the molise region and the gis analysis carried out within this study allowed us to recognize\nsome relevant features of human distribution through space and time.',
#  'this\ngis database represents, up to now, the most powerful tool to promote the\nknowledge of the archaeological heritage of the molise region worldwide\nand to address urban planning in the next years.',
#  'ettore valente*\ndipartimento di scienze della terra, dell’ambiente e delle risorse\nuniversità degli studi di napoli federico ii\nettore.valente@unina.it\nmarilena cozzolino\ndipartimento di scienze umanistiche, sociali e della formazione\nuniversità del molise\nmarilena.cozzolino@unimol.it\nacknowledgements\nwe are grateful to the superintendence for archaeological heritage of the molise region\nthat allowed us to analyse their entire archives, including historical documents.',
#  'we also\nwish to thank dr. antonella golino and dr. rosa cannavacciuolo that have participated\nto the first collection of data in the frame of the project “conoscere per competere”.',
#  'references\naa.vv.',
#  '1980, sannio: pentri e frentani dal vi al i sec.',
#  'a.c., catalogo della mostra, roma,\nde luca.',
#  'amato v., aucelli p.p.c., capozzi a., de benedittis g.f., pappone g., rosskopf c.m.',
#  '2013, environmental changes in the boiano intramontane basin (molise, italy) since the times of ancient bovianum (ivth century bc), «alpine and mediterranean quaternary»,\n26, 1, 15-29.',
#  '* corresponding author.',
#  '383\ngis mapping of the archaeological sites in the molise region (italy)\namato v., cozzolino m., de benedittis g., di paola g., gentile v., giordano c.,\nmarino p., rosskopf c.m., valente e. 2016, an integrated quantitative approach to assess the archaeological heritage in highly anthropized areas: the case study of aesernia\n(southern italy), «acta imeko», 5, 2, 33-43.\nbarker g. 1995, the biferno valley survey.',
#  'the archaeological and geomorphological record, london, leicester university press.',
#  'caliò l.m., lepone a., lippolis e. 2011, larinum.',
#  'the development of the forum area, in f.\ncolivicchi (ed.',
#  '), local cultures of south italy and sicily in the late republican period: between hellenism and rome, «journal of roman archaeology», suppl.',
#  '83, 7a-111.',
#  'capini s. 1990, venafro (isernia): il teatro romano, «bollettino di archeologia», 229-232.\ncapini s., de benedittis g. 2000, pietrabbondante: guida agli scavi, campobasso, tipoli- tografia fotolampo.',
#  'catalano d., paone n., terzani c. 2001, isernia, isernia, cosmo iannone editore.',
#  'ceglia v. 1988, lo scavo della necropoli di vicenne, «conoscenze», 4, 31-48.\nceglia v. 2000, campochiaro (cb).',
#  'la necropoli di vicenne, in e. arslan, m. buora (eds.)',
#  'l’oro degli avari.',
#  'popolo delle steppe in europa, milano, inform edizioni, 212-221.\nceglia v. 2015, saepinum.',
#  'il sistema idrico e fognante, «considerazioni di storia e archeo- logia», 8, 23-32.\nceglia v., marchetta i.',
#  '2012, nuovi dati dalla necropoli di vicenne a campochiaro, in c.\nebanista, m. rotili (eds.',
#  '), la trasformazione del mondo romano e le grandi migrazioni.',
#  'nuovi popoli dall’europa settentrionale e centro-orientale alle coste del mediterraneo.',
#  'atti del convegno internazionale di studi (cimitile-santa maria capua vetere 2011), giornate sulla tarda antichità e il medioevo, 4, cimitile, tavolario, 217-238.\nchapman h. 2006, landscape archaeology and gis, gloucestershire, stroud.',
#  'coarelli f., la regina a.',
#  '1984, abruzzo, molise, guide archeologiche laterza, roma-bari,\nlaterza.',
#  'coltorti m., cremaschi m., delitala m.c., esu d., fornaseri m., mcpherron a.,\nnicoletti m., van otterloo r., peretto c., sala p., schmidt v., sevink j., 1982,\nreversed magnetic polarity at isernia la pineta, a new lower paleolithic site in central\nitaly, «nature», 300, 173-176.\ncoltorti m., ferand, g., marzoli a., peretto c., ton that t., voinchet p., bahain\nj.j., minelli a., thun hohenstein u.',
#  '2005, new 40ar/39ar, stratigraphic and paleo- climatic data on the isernia la pineta lower paleolithic site, molise, italy, «quaternary international», 131, 11-22.\nconventi m. 2004, città romane di fondazione, roma, l’erma di bretschneider.',
#  'de benedittis g. 1974, il centro sannitico di monte vairano presso campobasso, in docu- menti di antichità italiche e romane.',
#  'soprintendenza ai monumenti alle antichità e alle\nbelle arti del molise, 5, campobasso, 16-17.\nde benedittis g. 1977, bovianum ed il suo territorio: primi appunti di topografia storica, isernia, laveglia ed.',
#  'de benedittis g. 1979, abruzzo molise.',
#  'guide d’italia, milano, touring club d’italia.',
#  'de benedittis g. 1981, saepinum: città e territorio tra tardo impero e basso medioevo, «archivio storico per le province napoletane», 20, 7-30.\nde benedittis g. 1988, monte vairano, la casa di “ln”, catalogo della mostra, campo- basso, studio emmezeta.',
#  'de benedittis g. 2004, bovianum, aesernia, monte vairano: considerazioni sull’evoluzione\ndell’insediamento nel sannio pentro, in h. jones (ed.',
#  '), samnium.',
#  'settlement and cultural\nchange, archaeologia transatlantica 22, providence, brown university, 26-28.\nde benedittis g. 2008, molise: esperienze di survey: riccia, oratino, castropignano, isernia,\nistituto regionale per gli studi storici del molise.',
#  'de tata p. 1990, l’anfiteatro romano di larinum: le campagne di scavo 1987-1988, «cono- scenze», 6, 129-137.',
#  '384\ne. valente, m. cozzolino\ndi niro a.',
#  '1991, larinum, in s. capini, a. di niro (eds.',
#  '), samnium.',
#  'archeologia del molise,\ncatalogo della mostra, roma, quasar, 263-267.\ndi niro a., santone m., santoro w. 2010, carta del rischio archeologico nell’area del\ncratere.',
#  'primi dati di survey nei comuni colpiti dal sisma del 2002, campobasso, soprintendenza per i beni archeologici del molise.',
#  'di rocco g. 2009, castelli e borghi murati della contea di molise (secoli x-xiv), quaderni\ndi archeologia medievale 10, firenze, all’insegna del giglio.',
#  'djindjian f. 1998, gis usage in worldwide archaeology, in p. moscati (ed.',
#  '), methodological trends and future perspectives in the application of gis in archaeology, «archeologia e calcolatori», 9, 19-30.\ngaggiotti m., matteini chiari m. 1979, sepino.',
#  'archeologia e continuità, campobasso, edizioni enne.',
#  'gillings m., wheatley d. 2003, spatial technology and archaeology.',
#  'the archaeological applications of gis, london, taylor&francis.',
#  'grimaldi s. 2005, nuove ricerche sul paleolitico del molise.',
#  'materie prime, industrie litiche, insediamenti, isernia, centro europeo di ricerche preistoriche.',
#  'la regina a.',
#  '2014, pietrabbondante e il sannio antico, «almanacco del molise», 161-208.\nlippolis e., guidone s., lepone a., mazzilli g. 2015, larino: ricerche nell’area del foro, «scienze dell’antichità», 21, 1, 69-100.\nmarazzi f., delogu p.',
#  '(eds.)',
#  '1996, san vincenzo al volturno: cultura, istituzioni, economia,\nmonteroduni, edizioni cep.',
#  'marino l., carnevale s., pesino c. 2003, guida ai castelli del molise, pescara, carsa\nedizioni.',
#  'mastronardi n. 2004, i giganti verdi.',
#  'immagini, incontri e suggestioni lungo i tratturi del molise, cerro al volturno, volturnia ed.',
#  'mataluna s. 2012, il territorio tra allifae e venafrum, in quilici, quilici 2011, 11-128.\nmatteini chiari m., gaggiotti m., de benedettis g. 1984, saepinum-sepino, campo- basso, edizioni enne.',
#  'meini m., di felice g., petrella m. 2018, geotourism perspectives for transhumance routes.',
#  'analysis, requalification and virtual tools for the geoconservation management\nof the drove roads in southern italy, «geosciences», 8, 10, 368.\nminelli a., peretto c. 2006, preistoria in molise.',
#  'gli insediamenti del territorio di isernia, roma, aracne editrice.',
#  'minotti m., giancola c., di marzio p., di martino p. 2018, land use dynamics of drove roads: the case of tratturo castel di sangro-lucera (molise, italy), «land», 7, 3.\nmorel j.p. 1984, il santuario sannitico di vastogirardi.',
#  'resoconto degli scavi archeologici degli anni 1971, 1973 e 1974, in sannio: pentri e frentani dal vi al i secolo a.c. atti\ndel convegno (isernia 1980), campobasso, enne.',
#  'oakley s.p.',
#  '1995, the hill-forts of the samnites, rome, archaeological monographs of the british school of rome.',
#  'pagano m., ceccarelli a., d’andrea a.',
#  '2005, la ripresa delle esplorazioni e degli scavi nel santuario italico di vastogirardi (is), in d. caiazza (ed.',
#  '), italica ars.',
#  'studi in onore di\ngiovanni colonna per il premio i sanniti, piedimonte matese, grillo, 451-505.\npaone n., schioppa a., marazzi f., vignone f., speciale l., de luca roberti l., shaw\na.',
#  '2004, san vincenzo al volturno, isernia, cosmo iannone editore.',
#  'pellicano a.',
#  '2007, geografia e storia dei tratturi del mezzogiorno, roma, aracne.',
#  'peretto c. 2013, isernia la pineta, isernia, cosmo iannone editore.',
#  'quilici l., quilici gigli s. 2011, carta archeologica e ricerche in campania.',
#  'fascicolo 5:\ncomune di venafro, roma, atlante tematico di topografia antica, suppl.',
#  'xv.',
#  'rufo e. 2011, note sulla preistoria dell’alta valle del volturno, in a. testa (ed.',
#  '), l’abbazia\ndi san vincenzo e l’alta valle del volturno, «archeomolise», 3, 8, 8-17.',
#  '385\ngis mapping of the archaeological sites in the molise region (italy)\nrufo e., minelli a., lembo g., paglione b., peretto c. 2010, la preistoria dell’alto molise.',
#  'una panoramica, «archeomolise», 2, 4, 6-19.\nsantorelli s. 2013, trivento, testimonianze dal passato, «archeomolise», 14, 22-35.\nsardella b.',
#  '2011, fra terventum e aufidene.',
#  'carta archeologica dei territori montani del sannio pentro nord-occidentale, tesi di dottorato, seconda università degli studi di napoli.',
#  'stek t.d.',
#  '2010, cult places and cultural change in republican italy, amsterdam, amsterdam\nuniversity press.',
#  'stek t.d., modrall e.b., kalkers r.a.a., van otterloo r.h., sevink j.',
#  '2015, an early\nroman colonial landscape in the apennine mountains: landscape archaeological research in the territory of aesernia (central-southern italy), «analysis archaeologica»,\n1, 229-291.\nterzani c. 2005, scavo archeologico della cinta muraria di aesernia, «fold&r.',
#  'fasti on\nline documents & research», 35, 1-2.\nzilli i.',
#  '2010, atlante delle emergenze culturali del molise.',
#  'risultati, riflessioni ed implicazioni\ndi un primo censimento, campobasso, palladino editore.',
#  'abstract\nthe molise region, on the adriatic coast of southern italy, experienced human presence\nsince prehistoric times.',
#  'site distribution is not homogeneous throughout the region and a com- prehensive census of all known archaeological sites has never been performed.',
#  'in this paper,\nwe present the results of a three-year project for the gis mapping and database creation for\nall the known archaeological sites of the molise region.',
#  'as a result, 3111 archaeological sites\nhave been mapped, stored in a gis database and then analysed through spatial analyst tools.',
#  'most of the mapped sites have been classified as area of archaeological finds (57.1% of the\ntotal sites), followed by settlements (12.9%) and buildings (9.8%).',
#  'site distribution is mainly\nclustered along the biferno river valley, in the central and in the south-western sectors of the\nmolise region.',
#  'the largest human occupation of the region occurred during the samnite and\nroman ages.',
#  'archaeological sites are also located at different elevation a.s.l., with a general\nincreasing trend of site elevation through time.',
#  'this gis database is, up to now, the most\ncomplete census of archaeological sites in the study area, thus representing a powerful tool\nto promote the archaeological heritage of the molise region and to address urban planning.']

# %%
# or more commonly, we can tokenize into words, which splits the sentences into its parts of speech
transcript_words = word_tokenize(transcript)
transcript_words
# Out:
# ['367',
#  'archeologia',
#  'e',
#  'calcolatori',
#  '30',
#  ',',
#  '2019',
#  ',',
#  '367-385',
#  'gis',
#  'mapping',
#  'of',
#  'the',
#  'archaeological',
#  'sites',
#  'in',
#  'the',
#  'molise',
#  'region',
#  '(',
#  'italy',
#  ')',
#  '1.',
#  'introduction',
#  'the',
#  'molise',
#  'region',
#  'is',
#  'in',
#  'the',
#  'northern',
#  'sector',
#  'of',
#  'southern',
#  'italy',
#  'and',
#  'it',
#  'is',
#  'spread',
#  'from',
#  'the',
#  'apennine',
#  'chain',
#  'to',
#  'the',
#  'adriatic',
#  'coast',
#  '.',
#  'this',
#  'area',
#  'experienced',
#  'human',
#  'presence',
#  'since',
#  'prehistoric',
#  'times',
#  ',',
#  'as',
#  'it',
#  'is',
#  'testified',
#  'by',
#  'its',
#  'rich',
#  'archaeological',
#  'and',
#  'architectural',
#  'heritage',
#  '(',
#  'de',
#  'benedittis',
#  '1979',
#  ';',
#  'coarelli',
#  ',',
#  'la',
#  'regina',
#  '1984',
#  ')',
#  '1',
#  '.',
#  'the',
#  'oldest',
#  'human',
#  'presence',
#  'in',
#  'molise',
#  'is',
#  'represented',
#  'by',
#  'the',
#  'upper',
#  'palaeolithic',
#  'settlement',
#  'of',
#  'isernia',
#  'la',
#  'pineta',
#  ',',
#  'dated',
#  'back',
#  'at',
#  'about',
#  '600.000',
#  'years',
#  'bp',
#  '(',
#  'coltorti',
#  'et',
#  'al',
#  '.',
#  '1982',
#  ',',
#  '2005',
#  'and',
#  'references',
#  ';',
#  'peretto',
#  '2013',
#  ')',
#  '.',
#  'the',
#  'site',
#  'represents',
#  'a',
#  'unique',
#  'example',
#  'in',
#  'the',
#  'history',
#  'of',
#  'the',
#  'human',
#  'frequentation',
#  'in',
#  'europe',
#  'for',
#  'the',
#  'presence',
#  'of',
#  'a',
#  'considerable',
#  'number',
#  'of',
#  'paleontological',
#  'finds',
#  'associated',
#  'to',
#  'lithic',
#  'artefacts',
#  '.',
#  'other',
#  'more',
#  'recent',
#  'and',
#  'relevant',
#  'prehistoric',
#  'sites',
#  'have',
#  'been',
#  'also',
#  'found',
#  'in',
#  'the',
#  'municipalities',
#  'of',
#  'pescopennataro',
#  '(',
#  'rio',
#  'verde',
#  'site',
#  ')',
#  ',',
#  'carovilli',
#  '(',
#  'piana',
#  's.',
#  'mauro',
#  'and',
#  'fonte',
#  'curello',
#  'sites',
#  ')',
#  ',',
#  'rocchetta',
#  'a',
#  'volturno',
#  '(',
#  'grotta',
#  'reali',
#  'site',
#  ')',
#  ',',
#  'civitanova',
#  'del',
#  'sannio',
#  '(',
#  'morricone',
#  'del',
#  'pesco',
#  'site',
#  ')',
#  ',',
#  'cerro',
#  'al',
#  'volturno',
#  '(',
#  'monte',
#  's.',
#  'croce',
#  'site',
#  ')',
#  'and',
#  'in',
#  'the',
#  'biferno',
#  'valley',
#  '(',
#  'barker',
#  '1995',
#  ';',
#  'grimaldi',
#  '2005',
#  ';',
#  'minelli',
#  ',',
#  'peretto',
#  '2006',
#  ';',
#  'rufo',
#  'et',
#  'al',
#  '.',
#  '2010',
#  ';',
#  'rufo',
#  '2011',
#  ')',
#  '.',
#  'after',
#  'prehistoric',
#  'times',
#  ',',
#  'the',
#  'most',
#  'relevant',
#  'archaeological',
#  'findings',
#  'can',
#  'be',
#  'chronologically',
#  'dated',
#  'to',
#  'the',
#  'samnite',
#  'age',
#  '(',
#  'ranging',
#  'from',
#  'the',
#  'v',
#  'to',
#  'the',
#  'i',
#  'century',
#  'bc',
#  ')',
#  '.',
#  'in',
#  'this',
#  'period',
#  ',',
#  'several',
#  'villages',
#  'and',
#  'about',
#  'thirty',
#  'samnite',
#  'fortifications',
#  'were',
#  'built',
#  ',',
#  'the',
#  'latter',
#  'being',
#  'in',
#  'correspondence',
#  'to',
#  'some',
#  'of',
#  'the',
#  'highest',
#  'topographic',
#  'peaks',
#  'of',
#  'the',
#  'molise',
#  'region',
#  '.',
#  'these',
#  'fortifications',
#  'were',
#  'built',
#  'with',
#  'the',
#  'technique',
#  'of',
#  'opera',
#  'poligonalis',
#  'and',
#  'were',
#  'connected',
#  'to',
#  'each',
#  'other',
#  'through',
#  'transhumance',
#  'routes',
#  ',',
#  'the',
#  'so',
#  'called',
#  'tratturi',
#  '(',
#  'aa.vv',
#  '.',
#  '1980',
#  ';',
#  'pellicano',
#  '2007',
#  ';',
#  'meini',
#  ',',
#  'di',
#  'felice',
#  ',',
#  'petrella',
#  '2018',
#  ';',
#  'minotti',
#  'et',
#  'al',
#  '.',
#  '2018',
#  ')',
#  '.',
#  'the',
#  'remains',
#  'of',
#  'pietrabbondante',
#  '(',
#  'fig',
#  '.',
#  '1',
#  'a',
#  ')',
#  '(',
#  'capini',
#  ',',
#  'de',
#  'benedittis',
#  '2000',
#  ';',
#  'la',
#  'regina',
#  '2014',
#  ')',
#  ',',
#  'the',
#  'small',
#  'temples',
#  'of',
#  'vastogirardi',
#  '(',
#  'morel',
#  '1984',
#  ';',
#  'pagano',
#  ',',
#  'ceccarelli',
#  ',',
#  'd',
#  '’',
#  'andrea',
#  '2005',
#  ')',
#  'and',
#  's.',
#  'giovanni',
#  'in',
#  'galdo',
#  '(',
#  'stek',
#  '2010',
#  ')',
#  ',',
#  'the',
#  'fortifications',
#  'of',
#  'terravecchia',
#  'di',
#  'sepino',
#  '(',
#  'matteini',
#  'chiari',
#  ',',
#  'gaggiotti',
#  ',',
#  'de',
#  'benedettis',
#  '1984',
#  ')',
#  'and',
#  'monte',
#  'vairano',
#  '(',
#  'de',
#  'benedittis',
#  '1974',
#  ',',
#  '1988',
#  ',',
#  '2004',
#  ')',
#  'are',
#  'amazing',
#  'examples',
#  'of',
#  'the',
#  'samnites',
#  '’',
#  'culture',
#  '.',
#  'the',
#  'samnite',
#  'age',
#  'ceased',
#  'with',
#  'the',
#  'arrive',
#  'of',
#  'the',
#  'romans',
#  ',',
#  'who',
#  'dominated',
#  'the',
#  'entire',
#  'region',
#  'in',
#  'the',
#  'period',
#  'between',
#  'the',
#  'i',
#  'century',
#  'bc',
#  'and',
#  'the',
#  'v',
#  'century',
#  'ad',
#  '.',
#  '1',
#  'for',
#  'this',
#  'kind',
#  'of',
#  'study',
#  ',',
#  'the',
#  'bibliographic',
#  'research',
#  'just',
#  'took',
#  'into',
#  'account',
#  'the',
#  'most',
#  'relevant',
#  'and',
#  'general',
#  'papers',
#  'and',
#  'volumes',
#  'published',
#  'for',
#  'each',
#  'archaeological',
#  'site',
#  ',',
#  'without',
#  'considering',
#  'the',
#  'large',
#  'amount',
#  'of',
#  'papers',
#  'regarding',
#  'local',
#  'and',
#  'specific',
#  'investigations',
#  '.',
#  '368',
#  'e.',
#  'valente',
#  ',',
#  'm.',
#  'cozzolino',
#  'roman',
#  'findings',
#  'are',
#  'evenly',
#  'widespread',
#  'in',
#  'molise',
#  ',',
#  'and',
#  'the',
#  'city',
#  'of',
#  'saepinum',
#  '(',
#  'fig',
#  '.',
#  '1',
#  'b',
#  ')',
#  'is',
#  'considered',
#  'the',
#  'symbol',
#  'of',
#  'the',
#  'history',
#  'of',
#  'roman',
#  'civilization',
#  '.',
#  'saepinum',
#  'was',
#  'a',
#  'samnite',
#  'commercial',
#  'forum',
#  'and',
#  'service',
#  'centre',
#  ',',
#  'then',
#  'it',
#  'became',
#  'a',
#  'roman',
#  'municipium',
#  'and',
#  ',',
#  'later',
#  ',',
#  'it',
#  'was',
#  'transformed',
#  'into',
#  'a',
#  'medieval',
#  'and',
#  'modern',
#  'rural',
#  'village',
#  '(',
#  'gaggiotti',
#  ',',
#  'matteini',
#  'chiari',
#  '1979',
#  ';',
#  'de',
#  'benedittis',
#  '1981',
#  ';',
#  'ceglia',
#  '2015',
#  ')',
#  '.',
#  'other',
#  'examples',
#  'of',
#  'important',
#  'roman',
#  'towns',
#  'are',
#  'aesernia',
#  '(',
#  'fig',
#  '.',
#  '1',
#  'c',
#  ')',
#  '(',
#  'catalano',
#  ',',
#  'paone',
#  ',',
#  'terzani',
#  '2001',
#  ';',
#  'terzani',
#  '2005',
#  ';',
#  'stek',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ';',
#  'amato',
#  'et',
#  'al',
#  '.',
#  '2016',
#  ')',
#  ',',
#  'venafrum',
#  '(',
#  'capini',
#  '1990',
#  ';',
#  'conventi',
#  '2004',
#  ';',
#  'mataluna',
#  '2012',
#  ')',
#  ',',
#  'bovianum',
#  '(',
#  'de',
#  'benedittis',
#  '1977',
#  ';',
#  'amato',
#  'et',
#  'al',
#  '.',
#  '2013',
#  'and',
#  'references',
#  ')',
#  'and',
#  'larinum',
#  '(',
#  'de',
#  'tata',
#  '1990',
#  ';',
#  'di',
#  'niro',
#  '1991',
#  ';',
#  'caliò',
#  ',',
#  'lepone',
#  ',',
#  'lippolis',
#  '2011',
#  ';',
#  'lippolis',
#  'et',
#  'al',
#  '.',
#  '2015',
#  ')',
#  '.',
#  'medieval',
#  'findings',
#  'include',
#  ',',
#  'among',
#  'all',
#  ',',
#  'the',
#  'monastery',
#  'of',
#  'san',
#  'vincenzo',
#  'al',
#  'volturno',
#  '(',
#  'fig',
#  '.',
#  '1',
#  'd',
#  ')',
#  '(',
#  'marazzi',
#  ',',
#  'delogu',
#  '1996',
#  ';',
#  'paone',
#  'et',
#  'al',
#  '.',
#  '2004',
#  ')',
#  'and',
#  'the',
#  'necropolis',
#  'of',
#  'campochiaro',
#  '(',
#  'ceglia',
#  '1988',
#  ',',
#  '2000',
#  'and',
#  'references',
#  ';',
#  'ceglia',
#  ',',
#  'marchetta',
#  '2012',
#  ')',
#  ',',
#  'both',
#  'testifying',
#  'the',
#  'early',
#  'medieval',
#  'phase',
#  '.',
#  'the',
#  'cathedrals',
#  'of',
#  'trivento',
#  ',',
#  'guardialfiera',
#  ',',
#  'termoli',
#  'and',
#  'larino',
#  'and',
#  'the',
#  'castles',
#  'of',
#  'civitacampomarano',
#  ',',
#  'roccamandolfi',
#  ',',
#  'cerro',
#  'al',
#  'volturno',
#  ',',
#  'termoli',
#  ',',
#  'venafro',
#  ',',
#  'gambatesa',
#  'and',
#  'campobasso',
#  'are',
#  'also',
#  'noteworthy',
#  'evidences',
#  'of',
#  'medieval',
#  'age',
#  ',',
#  'whose',
#  'stories',
#  'and',
#  'transformations',
#  'represent',
#  'important',
#  'pages',
#  'of',
#  'the',
#  'molise',
#  'history',
#  '(',
#  'marino',
#  ',',
#  'carnevale',
#  ',',
#  'pesino',
#  '2003',
#  ';',
#  'di',
#  'rocco',
#  '2009',
#  ')',
#  '.',
#  'in',
#  'the',
#  'last',
#  'years',
#  ',',
#  'both',
#  'the',
#  'superintendency',
#  'for',
#  'the',
#  'archaeological',
#  'heritage',
#  'of',
#  'the',
#  'molise',
#  'region',
#  'and',
#  'different',
#  'national',
#  'and',
#  'international',
#  'academic',
#  'teams',
#  'carried',
#  'out',
#  'numerous',
#  'archaeological',
#  'excavations',
#  'and',
#  'explorations',
#  'in',
#  'the',
#  'entire',
#  'molise',
#  'region',
#  '.',
#  'as',
#  'a',
#  'result',
#  ',',
#  'some',
#  'archaeological',
#  'contexts',
#  'can',
#  'now',
#  'rely',
#  'on',
#  'a',
#  'rich',
#  'literature',
#  'and',
#  'updated',
#  'results',
#  ',',
#  'whereas',
#  'other',
#  'areas',
#  'still',
#  'require',
#  'a',
#  'detailed',
#  'overall',
#  'analysis',
#  'and',
#  ',',
#  'especially',
#  ',',
#  'a',
#  'systematic',
#  'study',
#  '.',
#  'moreover',
#  ',',
#  'many',
#  'archaeological',
#  'materials',
#  'derived',
#  'from',
#  'emergency',
#  'excavations',
#  'during',
#  'either',
#  'public',
#  'or',
#  'private',
#  'works',
#  'are',
#  'unstudied',
#  '.',
#  'in',
#  'addition',
#  ',',
#  'there',
#  'is',
#  'a',
#  'lack',
#  'of',
#  'an',
#  'organic',
#  'and',
#  'complete',
#  '“',
#  'reading',
#  '”',
#  'of',
#  'all',
#  'the',
#  'known',
#  'data',
#  'and',
#  'the',
#  'concrete',
#  'need',
#  'to',
#  'acquire',
#  'additional',
#  'information',
#  'on',
#  'areas',
#  'that',
#  'have',
#  'never',
#  'been',
#  'investigated',
#  'to',
#  'date',
#  '.',
#  'in',
#  'order',
#  'to',
#  'standardize',
#  'and',
#  'store',
#  'the',
#  'myriad',
#  'of',
#  'archaeological',
#  'data',
#  'from',
#  'the',
#  'molise',
#  'region',
#  ',',
#  'from',
#  '2013',
#  'until',
#  'present',
#  ',',
#  'a',
#  'fruitful',
#  'collaboration',
#  'between',
#  'the',
#  'university',
#  'of',
#  'molise',
#  ',',
#  'the',
#  'regional',
#  'directorate',
#  'of',
#  'cultural',
#  'heritage',
#  'of',
#  'molise',
#  'and',
#  'the',
#  'administrative',
#  'division',
#  'of',
#  'molise',
#  'has',
#  'led',
#  'to',
#  'undertake',
#  'significant',
#  'actions',
#  'of',
#  'intervention',
#  'for',
#  'the',
#  'knowledge',
#  'and',
#  'the',
#  'preservation',
#  'of',
#  'the',
#  'ancient',
#  'landscape',
#  ',',
#  'according',
#  'to',
#  'the',
#  'following',
#  'workflow',
#  ':',
#  '–',
#  'census',
#  'of',
#  'all',
#  'known',
#  'archaeological',
#  'findings',
#  'of',
#  'the',
#  'molise',
#  'region',
#  ...]

# %%
# now remember that huge block of stopwords manually typed out in the sample block of code from the first lesson? That comes built in to NLTK as you may have guessed from the earlier import statment
# we can assign the NLTK stopwords to a variable like so:
stop_words = stopwords.words('english')

# and then remove the stopwords from out text using a loop to check if each word in the transcript and only keep the words that are NOT in out stopword list
filtered_transcript_words = []
for word in transcript_words:
    if word not in stop_words:
        filtered_transcript_words.append(word)

# %%
# finally, we can simply find word frequeny with NLTK's frequnecy distribution function
from nltk import FreqDist

transcript_fdist = FreqDist(filtered_transcript_words)
transcript_fdist.most_common(10)
# Out:
# [(',', 643),
#  ('.', 305),
#  (')', 187),
#  ('(', 181),
#  ('archaeological', 128),
#  ('sites', 126),
#  ('molise', 78),
#  ('region', 63),
#  (';', 56),
#  ('site', 51)]

# %%
# now, as you can see, our list is topped by punctuation and contractions!

# to remove punctuation, we can use Python's string library to create a list of punctuation
from string import punctuation
punctuation = list(punctuation)

# and luckily, you can modify your stopwords and punctuation lists like any other list!
# let's add "n't", "'s", and "would"
# to add multiple elements to a list at once, we use extend() rather that append()
stop_words.extend(["n't", "'s", 'would'])

# %%
# let's re-run with our new stopwords and punctuation list to see the improved results
filtered_transcript_words = []
for word in transcript_words:
    if word not in stop_words and word not in punctuation:
        filtered_transcript_words.append(word)

transcript_fdist = FreqDist(filtered_transcript_words)
transcript_fdist.most_common(10)
# Out:
# [('archaeological', 128),
#  ('sites', 126),
#  ('molise', 78),
#  ('region', 63),
#  ('site', 51),
#  ('di', 49),
#  ('fig', 42),
#  ('age', 35),
#  ('–', 32),
#  ('del', 31)]

# %%
# now that we have a word frequency list, we can even use NLTK for concordance analysis (seeing word in context)
# we can choose a word from the word frequency list, and search the original tokenized text for it after making it a Text object
from nltk.text import Text

text_list = Text(transcript_words)
text_list.concordance("work", lines=52)
# Out:
# Displaying 3 of 3 matches:
# esigns . 2. material and methods the work has been based on separate phases of
# te images , topographic maps , field work or aerial photos ; – georeference qu
# h , bibliographic research and field work ; – description ( string , length 25

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from string import punctuation
punctuation = list(punctuation)

nltk.download('punkt')
nltk.download('stopwords')

transcript = open('gismapping.txt', encoding="utf-8").read().lower()

transcript_words = word_tokenize(transcript)

stop_words = stopwords.words('english')
stop_words.extend(["n't", "'s", 'would'])

filtered_transcript_words = []
for word in transcript_words:
    if word not in stop_words and word not in punctuation:
        filtered_transcript_words.append(word)

transcript_fdist = FreqDist(filtered_transcript_words)
transcript_fdist.most_common(10)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('archaeological', 128),
#  ('sites', 126),
#  ('molise', 78),
#  ('region', 63),
#  ('site', 51),
#  ('di', 49),
#  ('fig', 42),
#  ('age', 35),
#  ('–', 32),
#  ('del', 31)]

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from string import punctuation
punctuation = list(punctuation)

nltk.download('punkt')
nltk.download('stopwords')

transcript = open('gismapping.txt', encoding="utf-8").read().lower()

transcript_words = word_tokenize(transcript)

stop_words = stopwords.words('english')
stop_words.extend(["n't", "'s", 'would'])

filtered_transcript_words = []
for word in transcript_words:
    if word not in stop_words and word not in punctuation:
        filtered_transcript_words.append(word)

transcript_fdist = FreqDist(filtered_transcript_words)
transcript_fdist.most_common(10)

# now that we have a word frequency list, we can even use NLTK for concordance analysis (seeing word in context)
# we can choose a word from the word frequency list, and search the original tokenized text for it after making it a Text object
from nltk.text import Text

text_list = Text(transcript_words)

# Get the 10 most common words
common_words = [word for word, _ in transcript_fdist.most_common(10)]

# Loop through the common words and get concordance for each
for word in common_words:
    print(f"Concordance for '{word}':")
    text_list.concordance(word, lines=52)
    print("\n")
# Out:
# Concordance for 'archaeological':
# Displaying 52 of 128 matches:
# 19 , 367-385 gis mapping of the archaeological sites in the molise region ( it
#  as it is testified by its rich archaeological and architectural heritage ( de
# toric times , the most relevant archaeological findings can be chronologically
#  and volumes published for each archaeological site , without considering the
# oth the superintendency for the archaeological heritage of the molise region a
# emic teams carried out numerous archaeological excavations and explorations in
# ise region . as a result , some archaeological contexts can now rely on a rich
# tematic study . moreover , many archaeological materials derived from emergenc
# dardize and store the myriad of archaeological data from the molise region , f
# orkflow : – census of all known archaeological findings of the molise region t
# ime , of a detailed and updated archaeological database . – integration of thi
# c maps . 369 gis mapping of the archaeological sites in the molise region ( it
# . 1 – some of the most relevant archaeological sites in the molise region . a
# updated computerized map of the archaeological evidences of the study area as
# useful for the promotion of the archaeological heritage and a tool for more su
#  that include the collection of archaeological data , the collection of topogr
# al analysis . 2.1 collection of archaeological data the collection of a large
# of a large amount of data about archaeological sites within the molise region
# gation , published detail scale archaeological researches carried out by both
# ntists have been analysed . the archaeological maps realized in the municipali
# wn data related to detail scale archaeological surveys . the monographs of the
# verviews on the distribution of archaeological sites during specific time span
# que attempt to take a census of archaeological sites in the molise region , re
# classical sites , 73 industrial archaeological remnants , 31 sites belonging t
#  an unprecedented collection of archaeological data in the frame of the projec
# sulted in the collection of 905 archaeological sites in the entire region . in
# tire region . in addition , 977 archaeological data collected by barker ( 1995
# r database . as a result , 1882 archaeological sites have been collected durin
# stigation , the archives of the archaeological superintendence have been analy
# ly , new and inedited data from archaeological impact assessment reports ( rel
# tigation led us to collect 3111 archaeological sites within the entire molise
# base creation all the collected archaeological sites have been listed in a poi
# eviously 371 gis mapping of the archaeological sites in the molise region ( it
# . the point shapefile , named “ archaeological sites ” , includes several fiel
# r isernia or campobasso ) where archaeological sites fall within ; – municipal
# erence system used to geolocate archaeological sites ( utm-wgs84 ) ; – z coord
# ographic map used to locate the archaeological site ( either 1:5000 or 1:25.00
# the method used to locate every archaeological site , either by web research ,
# irst , brief description of the archaeological sites , which have been subdivi
# d detailed description of every archaeological site ; – age_1 ( string , lengt
# b references where every single archaeological site has been derived from . 2.
# al analysis all the 3111 listed archaeological sites have been then analysed i
# en analysed by grouping all the archaeological sites in the age classes listed
# ted in the age_2 field of the “ archaeological site ” shapefile . archaeologic
# chaeological site ” shapefile . archaeological sites grouped for age have been
# his case , we have selected all archaeological sites with the same age and exp
# the value field . finally , the archaeological sites spatial distribution and
# le . we have then clipped the “ archaeological site ” shapefile with this buff
# ribution of all the 3111 mapped archaeological sites of the molise region is r
# reported in fig . 2. moreover , archaeological sites have been plotted on a 40
# san polo 373 gis mapping of the archaeological sites in the molise region ( it
# ality has the largest number of archaeological sites within its territory , wi
#
#
# Concordance for 'sites':
# Displaying 52 of 126 matches:
# 85 gis mapping of the archaeological sites in the molise region ( italy ) 1. in
# more recent and relevant prehistoric sites have been also found in the municipa
# i ( piana s. mauro and fonte curello sites ) , rocchetta a volturno ( grotta re
# 69 gis mapping of the archaeological sites in the molise region ( italy ) fig .
#  of the most relevant archaeological sites in the molise region . a ) remains o
#  amount of data about archaeological sites within the molise region has been ca
# akley 1995 ) and of the palaeolithic sites in molise ( grimaldi 2005 ) gave als
# n the distribution of archaeological sites during specific time span . the atla
# t to take a census of archaeological sites in the molise region , resulting in
# , resulting in the collection of 228 sites ( 124 classical sites , 73 industria
# lection of 228 sites ( 124 classical sites , 73 industrial archaeological remna
# ustrial archaeological remnants , 31 sites belonging to various categories ) .
# the collection of 905 archaeological sites in the entire region . in addition ,
#  . as a result , 1882 archaeological sites have been collected during this firs
# ed us to collect 3111 archaeological sites within the entire molise region . 2.
# ion all the collected archaeological sites have been listed in a point shapefil
# 71 gis mapping of the archaeological sites in the molise region ( italy ) menti
# t shapefile , named “ archaeological sites ” , includes several fields that hav
# or campobasso ) where archaeological sites fall within ; – municipality ( strin
# tem used to geolocate archaeological sites ( utm-wgs84 ) ; – z coord ( double ,
# ongitude and latitude of the plotted sites respectively ; – cartography ( strin
# ef description of the archaeological sites , which have been subdivided in 19 c
# f , more detailed description of the sites ; – description_1 to description_5 (
# s all the 3111 listed archaeological sites have been then analysed in a gis sof
# the areal distribution of the mapped sites , we performed a density analysis tr
# d by grouping all the archaeological sites in the age classes listed in the age
# al site ” shapefile . archaeological sites grouped for age have been then plott
# amined to verify a possible trend in sites distribution through time . in this
#  we have selected all archaeological sites with the same age and exported them
# field . finally , the archaeological sites spatial distribution and its relatio
# buffer and we have extracted all the sites located within 1000 m from both the
# f all the 3111 mapped archaeological sites of the molise region is reported in
# n fig . 2. moreover , archaeological sites have been plotted on a 40 m dtm of t
# unicipalities of the molise region . sites distribution enhances the occurrence
# 73 gis mapping of the archaeological sites in the molise region ( italy ) mates
# the largest number of archaeological sites within its territory , with 277 mapp
# thin its territory , with 277 mapped sites ( fig . 3a ) . it is followed by cas
#  it is followed by casacalenda ( 186 sites , fig . 3b ) , isernia ( 167 sites ,
# 6 sites , fig . 3b ) , isernia ( 167 sites , fig . 4a ) , guglionesi ( 162 site
# ites , fig . 4a ) , guglionesi ( 162 sites , fig . 4b ) , trivento ( 106 sites
#  sites , fig . 4b ) , trivento ( 106 sites , fig . 5a ) and campomarino ( 102 s
# s , fig . 5a ) and campomarino ( 102 sites , fig . 5b ) , that are the only mun
# es with more than 100 archaeological sites . other municipalities with a releva
#  a relevant number of archaeological sites are venafro ( 98 sites ) , agnone (
# rchaeological sites are venafro ( 98 sites ) , agnone ( 66 sites ) , termoli (
# e venafro ( 98 sites ) , agnone ( 66 sites ) , termoli ( 65 sites ) , castropig
# , agnone ( 66 sites ) , termoli ( 65 sites ) , castropignano ( 61 sites ) , bar
# li ( 65 sites ) , castropignano ( 61 sites ) , baranello ( 53 sites ) , macchia
# ignano ( 61 sites ) , baranello ( 53 sites ) , macchia valfortore ( 49 sites )
# 53 sites ) , macchia valfortore ( 49 sites ) , colle d ’ anchise and guardialfi
# e d ’ anchise and guardialfiera ( 46 sites ) , vinchiaturo ( 44 sites ) , morro
# iera ( 46 sites ) , vinchiaturo ( 44 sites ) , morrone del sannio ( 43 sites )
#
#
# Concordance for 'molise':
# Displaying 52 of 78 matches:
#  of the archaeological sites in the molise region ( italy ) 1. introduction th
# egion ( italy ) 1. introduction the molise region is in the northern sector of
#  ) 1 . the oldest human presence in molise is represented by the upper palaeol
# he highest topographic peaks of the molise region . these fortifications were
# n findings are evenly widespread in molise , and the city of saepinum ( fig .
# ns represent important pages of the molise history ( marino , carnevale , pesi
#  the archaeological heritage of the molise region and different national and i
# ions and explorations in the entire molise region . as a result , some archaeo
# iad of archaeological data from the molise region , from 2013 until present ,
# aboration between the university of molise , the regional directorate of cultu
# directorate of cultural heritage of molise and the administrative division of
#  and the administrative division of molise has led to undertake significant ac
# nown archaeological findings of the molise region through bibliographic analys
#  of the archaeological sites in the molise region ( italy ) fig . 1 – some of
# elevant archaeological sites in the molise region . a ) remains of pietrabbond
# out archaeological sites within the molise region has been carried out through
#  ) and of the palaeolithic sites in molise ( grimaldi 2005 ) gave also importa
# he atlas of cultural emergencies of molise ( zilli 2010 ) , edited by universi
# li 2010 ) , edited by university of molise , has been also analysed ; the latt
# nsus of archaeological sites in the molise region , resulting in the collectio
# d by the administrative division of molise . this project resulted in the coll
# directorate of cultural heritage of molise . consequently , new and inedited d
# haeological sites within the entire molise region . 2.2 collection of topograp
# scale 1:5000 ( technical map of the molise region ) and 1:25.000 ( i.g.m . top
# ble by the technical offices of the molise region . in addition , a 40 m dtm o
# n . in addition , a 40 m dtm of the molise region has been used . 2.3 gis data
#  of the archaeological sites in the molise region ( italy ) mentioned topograp
# ed topographic maps and on the 40 m molise dtm . the point shapefile , named “
#  have been then plotted on the 40 m molise dtm . furthermore , site elevation
#  mapped archaeological sites of the molise region is reported in fig . 2. more
# e been plotted on a 40 m dtm of the molise region together with a polyline sha
# rs of all the municipalities of the molise region . sites distribution enhance
#  of the archaeological sites in the molise region ( italy ) matese and campoch
# venafro to the sw. among the entire molise region , the larino municipality ha
# is the administrative centre of the molise region and the most populated town
# ites , plotted on a 40 m dtm of the molise region . black dots indicate the ar
# rs of all the municipalities of the molise region . 374 e. valente , m. cozzol
# ocated in the central sector of the molise region . furthermore , the analysis
#  of the archaeological sites in the molise region ( italy ) fig . 4 – map of t
# n and in the eastern sectors of the molise region , corresponding to the munic
#  the venafro plain ) sectors of the molise region , with sparse sporadic sites
#  of the archaeological sites in the molise region ( italy ) fig . 6 – density
#  of the archaeological sites of the molise region . the same areas resulted to
# dings in the central portion of the molise region and in the medium biferno ri
#  the central-western portion of the molise region . 378 e. valente , m. cozzol
#  of the archaeological sites in the molise region . white dots indicates archa
#  of the archaeological sites in the molise region ( italy ) palaeolithic ( med
# o analyse human distribution in the molise region . it represents , up to now
#  of the archaeological sites in the molise region ( italy ) correspondence of
# ey and in the central sector of the molise region . in addition , they were lo
#  of archaeological sites within the molise region and the gis analysis carried
#  the archaeological heritage of the molise region worldwide and to address urb
#
#
# Concordance for 'region':
# Displaying 52 of 63 matches:
#  archaeological sites in the molise region ( italy ) 1. introduction the molis
#  italy ) 1. introduction the molise region is in the northern sector of southe
# est topographic peaks of the molise region . these fortifications were built w
# e romans , who dominated the entire region in the period between the i century
# chaeological heritage of the molise region and different national and internat
# d explorations in the entire molise region . as a result , some archaeological
# archaeological data from the molise region , from 2013 until present , a fruit
# chaeological findings of the molise region through bibliographic analysis . –
#  archaeological sites in the molise region ( italy ) fig . 1 – some of the mos
#  archaeological sites in the molise region . a ) remains of pietrabbondante ;
# haeological sites within the molise region has been carried out through a two
#  archaeological sites in the molise region , resulting in the collection of 22
#  archaeological sites in the entire region . in addition , 977 archaeological
# ical sites within the entire molise region . 2.2 collection of topographic dat
# :5000 ( technical map of the molise region ) and 1:25.000 ( i.g.m . topographi
# the technical offices of the molise region . in addition , a 40 m dtm of the m
# addition , a 40 m dtm of the molise region has been used . 2.3 gis database cr
#  archaeological sites in the molise region ( italy ) mentioned topographic map
#  archaeological sites of the molise region is reported in fig . 2. moreover ,
# plotted on a 40 m dtm of the molise region together with a polyline shapefile
# ll the municipalities of the molise region . sites distribution enhances the o
# al and south-western sectors of the region . the north-eastern cluster is ne-s
#  archaeological sites in the molise region ( italy ) matese and campochiaro to
#  to the sw. among the entire molise region , the larino municipality has the l
# administrative centre of the molise region and the most populated town of the
# e most populated town of the entire region ( 49320 inhabitants ) , is characte
# plotted on a 40 m dtm of the molise region . black dots indicate the archaeolo
# ll the municipalities of the molise region . 374 e. valente , m. cozzolino fig
# in the central sector of the molise region . furthermore , the analysis 375 gi
#  archaeological sites in the molise region ( italy ) fig . 4 – map of the arch
# n the eastern sectors of the molise region , corresponding to the municipaliti
# nafro plain ) sectors of the molise region , with sparse sporadic sites in the
# sites in the central portion of the region . 377 gis mapping of the archaeolog
#  archaeological sites in the molise region ( italy ) fig . 6 – density map of
#  archaeological sites of the molise region . the same areas resulted to be occ
# n the central portion of the molise region and in the medium biferno river val
# y and in the central portion of the region . on the opposite , they were compl
# cking in the western portion of the region , with the only exception of few sp
# areas in the central portion of the region with some samnite finds . the same
# man finds distributed in the entire region and mirroring the three main cluste
# y and in the central portion of the region ( fig . 7h ) . on the opposite , po
# y and in the central portion of the region , being completely lacking in the r
# mpletely lacking in the rest of the region ( fig . 7i ) . recent archaeologica
# ntral-western portion of the molise region . 378 e. valente , m. cozzolino fig
#  archaeological sites in the molise region . white dots indicates archaeologic
#  archaeological sites in the molise region ( italy ) palaeolithic ( median val
# se human distribution in the molise region . it represents , up to now , the l
# ed sites , widespread in the entire region , with three main clusters located
# in the south-western sectors of the region , respectively . moreover , the hig
#  archaeological sites in the molise region ( italy ) correspondence of the his
# in the central sector of the molise region . in addition , they were located a
# geneously distributed in the entire region . in this period , and during the s
#
#
# Concordance for 'site':
# Displaying 51 of 51 matches:
# nd references ; peretto 2013 ) . the site represents a unique example in the h
# lities of pescopennataro ( rio verde site ) , carovilli ( piana s. mauro and f
#  rocchetta a volturno ( grotta reali site ) , civitanova del sannio ( morricon
# ova del sannio ( morricone del pesco site ) , cerro al volturno ( monte s. cro
# , cerro al volturno ( monte s. croce site ) and in the biferno valley ( barker
# es published for each archaeological site , without considering the large amou
# accurate description of every single site . moreover , fields have been named
# e name of the municipality where the site is located followed by a progressive
# e name of the municipality where the site is located ; – locality ( string , l
# at provide further information about site location ; – reference system ( stri
# e elevation above sea level of every site ; – point x ( double , precision 0 ,
# ap used to locate the archaeological site ( either 1:5000 or 1:25.000 scale to
#  used to locate every archaeological site , either by web research , satellite
# ain , based on how much reliable the site location is ; – research method ( st
# ethod used to recognize every single site , including web research , bibliogra
#  description of every archaeological site ; – age_1 ( string , length 254 ) ,
# ength 254 ) , a precise age of every site ; – age_2 ( string , length 254 ) ,
# es where every single archaeological site has been derived from . 2.4 gis spat
# densities ; method = planar . then , site distribution during different ages h
#  age_2 field of the “ archaeological site ” shapefile . archaeological sites g
#  the 40 m molise dtm . furthermore , site elevation ( expressed in meters abov
# meters above sea level ) respect the site age has been examined to verify a po
# ithin the table of attribute , using site elevation as the value field . final
# ve then clipped the “ archaeological site ” shapefile with this buffer and we
# es have been classified according to site typology of the “ description ” fiel
# tion ” field of the “ archaeological site ” shapefiles ( see material and meth
# een obtained . in addition , maximum site density values of 21 sites/km² and 1
# es have been classified according to site typology of the “ description ” fiel
# tion ” field of the “ archaeological site ” shapefiles ( see material and meth
# es have been classified according to site typology of the “ description ” fiel
# tion ” field of the “ archaeological site ” shapefiles ( see material and meth
# nsidered age . we have also analysed site distribution as a function of the si
# te distribution as a function of the site elevation ( expressed in meters abov
#  fig . 8 we report a box plot of the site elevation as a function of the site
#  site elevation as a function of the site age . it is possible to note that th
# is possible to note that the minimum site elevation is almost constant during
# a.s.l. ) . a decreasing trend of the site elevation has been recognized from t
# tion ” field of the “ archaeological site ” shapefiles described in the materi
# ection . moreover , the most diffuse site type is the archaeological finds gro
# lysed a possible correlation between site location and some either man-made (
#  58 sites of uncertain age . all the site typologies listed in fig . 9 fall wi
# s of uncertain age . again , all the site typologies listed in fig . 9 fall wi
# g . 9 – percentage of archaeological site typology respect to the total mapped
# ed sites . fig . 8 – box plot of the site elevation ( m a.s.l . ) as a functio
# ation ( m a.s.l . ) as a function of site age . moreover , this study provides
# cal finds , whereas the most diffuse site typologies , that reflect the occurr
#  la pineta , a new lower paleolithic site in central italy , « nature » , 300
#  isernia la pineta lower paleolithic site , molise , italy , « quaternary inte
# n presence since prehistoric times . site distribution is not homogeneous thro
# ( 12.9 % ) and buildings ( 9.8 % ) . site distribution is mainly clustered alo
# , with a general increasing trend of site elevation through time . this gis da
#
#
# Concordance for 'di':
# Displaying 49 of 49 matches:
# .vv . 1980 ; pellicano 2007 ; meini , di felice , petrella 2018 ; minotti et a
#  , the fortifications of terravecchia di sepino ( matteini chiari , gaggiotti
# rences ) and larinum ( de tata 1990 ; di niro 1991 ; caliò , lepone , lippolis
#  ( marino , carnevale , pesino 2003 ; di rocco 2009 ) . in the last years , bo
# ti , ripabottoni , rotello , s. croce di magliano , s. giuliano di puglia , ur
#  , s. croce di magliano , s. giuliano di puglia , ururi ( di niro , santone ,
# ano , s. giuliano di puglia , ururi ( di niro , santone , santoro 2010 ) , ise
# years . ettore valente * dipartimento di scienze della terra , dell ’ ambiente
#  delle risorse università degli studi di napoli federico ii ettore.valente @ u
# na.it marilena cozzolino dipartimento di scienze umanistiche , sociali e della
# . , cozzolino m. , de benedittis g. , di paola g. , gentile v. , giordano c. ,
# a ) : il teatro romano , « bollettino di archeologia » , 229-232. capini s. ,
# ia v. 1988 , lo scavo della necropoli di vicenne , « conoscenze » , 4 , 31-48.
# 0 , campochiaro ( cb ) . la necropoli di vicenne , in e. arslan , m. buora ( e
#  idrico e fognante , « considerazioni di storia e archeo- logia » , 8 , 23-32.
# i . 2012 , nuovi dati dalla necropoli di vicenne a campochiaro , in c. ebanist
# eo . atti del convegno internazionale di studi ( cimitile-santa maria capua ve
# 1-22. conventi m. 2004 , città romane di fondazione , roma , l ’ erma di brets
# omane di fondazione , roma , l ’ erma di bretschneider . de benedittis g. 1974
# edittis g. 1974 , il centro sannitico di monte vairano presso campobasso , in
# no presso campobasso , in docu- menti di antichità italiche e romane . soprint
#  ed il suo territorio : primi appunti di topografia storica , isernia , lavegl
# tis g. 1988 , monte vairano , la casa di “ ln ” , catalogo della mostra , camp
# edittis g. 2008 , molise : esperienze di survey : riccia , oratino , castropig
#  tata p. 1990 , l ’ anfiteatro romano di larinum : le campagne di scavo 1987-1
# eatro romano di larinum : le campagne di scavo 1987-1988 , « cono- scenze » ,
# 9-137 . 384 e. valente , m. cozzolino di niro a . 1991 , larinum , in s. capin
#  . 1991 , larinum , in s. capini , a. di niro ( eds . ) , samnium . archeologi
# lla mostra , roma , quasar , 263-267. di niro a. , santone m. , santoro w. 201
#  nell ’ area del cratere . primi dati di survey nei comuni colpiti dal sisma d
#  per i beni archeologici del molise . di rocco g. 2009 , castelli e borghi mur
# castelli e borghi murati della contea di molise ( secoli x-xiv ) , quaderni di
# di molise ( secoli x-xiv ) , quaderni di archeologia medievale 10 , firenze ,
# sediamenti , isernia , centro europeo di ricerche preistoriche . la regina a .
# o- basso , edizioni enne . meini m. , di felice g. , petrella m. 2018 , geotou
# ise . gli insediamenti del territorio di isernia , roma , aracne editrice . mi
# editrice . minotti m. , giancola c. , di marzio p. , di martino p. 2018 , land
# tti m. , giancola c. , di marzio p. , di martino p. 2018 , land use dynamics o
# e roads : the case of tratturo castel di sangro-lucera ( molise , italy ) , «
# el j.p. 1984 , il santuario sannitico di vastogirardi . resoconto degli scavi
# i e degli scavi nel santuario italico di vastogirardi ( is ) , in d. caiazza (
# ed . ) , italica ars . studi in onore di giovanni colonna per il premio i sann
# he in campania . fascicolo 5 : comune di venafro , roma , atlante tematico di
#  di venafro , roma , atlante tematico di topografia antica , suppl . xv . rufo
#  , in a. testa ( ed . ) , l ’ abbazia di san vincenzo e l ’ alta valle del vol
# sannio pentro nord-occidentale , tesi di dottorato , seconda università degli
# rato , seconda università degli studi di napoli . stek t.d . 2010 , cult place
# cavo archeologico della cinta muraria di aesernia , « fold & r . fasti on line
# sultati , riflessioni ed implicazioni di un primo censimento , campobasso , pa
#
#
# Concordance for 'fig':
# Displaying 42 of 42 matches:
#  ) . the remains of pietrabbondante ( fig . 1 a ) ( capini , de benedittis 2000
# n molise , and the city of saepinum ( fig . 1 b ) is considered the symbol of t
#  important roman towns are aesernia ( fig . 1 c ) ( catalano , paone , terzani
# nastery of san vincenzo al volturno ( fig . 1 d ) ( marazzi , delogu 1996 ; pao
#  sites in the molise region ( italy ) fig . 1 – some of the most relevant archa
# s of the molise region is reported in fig . 2. moreover , archaeological sites
# s territory , with 277 mapped sites ( fig . 3a ) . it is followed by casacalend
# followed by casacalenda ( 186 sites , fig . 3b ) , isernia ( 167 sites , fig .
#  , fig . 3b ) , isernia ( 167 sites , fig . 4a ) , guglionesi ( 162 sites , fig
# fig . 4a ) , guglionesi ( 162 sites , fig . 4b ) , trivento ( 106 sites , fig .
# , fig . 4b ) , trivento ( 106 sites , fig . 5a ) and campomarino ( 102 sites ,
#  . 5a ) and campomarino ( 102 sites , fig . 5b ) , that are the only municipali
# ence of only 6 archaeological sites . fig . 2 – spatial distribution of the map
# egion . 374 e. valente , m. cozzolino fig . 3 – map of the archaeological sites
# ological sites for square-kilometre ( fig . 6 ) . the analysis confirms the occ
#  sites in the molise region ( italy ) fig . 4 – map of the archaeological sites
# l sites 376 e. valente , m. cozzolino fig . 5 – map of the archaeological sites
# n one map . during the palaeolithic ( fig . 7a ) archaeological sites were main
#  sites in the molise region ( italy ) fig . 6 – density map of the archaeologic
#  in the medium biferno river valley ( fig . 7b ) . during the eneolithic ( fig
#  fig . 7b ) . during the eneolithic ( fig . 7c ) , the bronze age ( fig . 7d )
# ithic ( fig . 7c ) , the bronze age ( fig . 7d ) and the iron age ( fig . 7e )
# e age ( fig . 7d ) and the iron age ( fig . 7e ) , archaeological sites have be
# archaeological sites of samnite age ( fig . 7f ) are widespread all over the en
# same occurred during the roman time ( fig . 7g ) , with roman finds distributed
# the three main clusters recognized in fig . 1. medieval finds are spread in the
# n the central portion of the region ( fig . 7h ) . on the opposite , post-medie
# y lacking in the rest of the region ( fig . 7i ) . recent archaeological finds
#  7i ) . recent archaeological finds ( fig . 7j ) are very few with a random dis
# lly , 372 sites ( 12 % of the total , fig . 7k ) have an uncertain age and they
# egion . 378 e. valente , m. cozzolino fig . 7 – chronological distribution of t
# or if any correlation is present . in fig . 8 we report a box plot of the site
# ( dotted line within each box plot of fig . 8 ) highlight the occurrence of an
# y of archaeological finds is shown in fig . 9. type groups are those included i
# ( river ) features of the landscape ( fig . 10 ) . archaeological sites located
# 0 m from the tratturi are reported in fig . 10a . as tratturi appeared during t
# e . all the site typologies listed in fig . 9 fall within this buffer . in addi
# 00 m from main rivers are reported in fig . 10b . it includes 399 sites ( 13 %
# n , all the site typologies listed in fig . 9 fall within this buffer . 4. disc
# 006 ) . 380 e. valente , m. cozzolino fig . 9 – percentage of archaeological si
# y respect to the total mapped sites . fig . 8 – box plot of the site elevation
#  it is worthy to note that , anyway , fig . 10 – a ) white dots indicate archae
#
#
# Concordance for 'age':
# Displaying 35 of 35 matches:
#  chronologically dated to the samnite age ( ranging from the v to the i century
#  the samnites ’ culture . the samnite age ceased with the arrive of the romans
# also noteworthy evidences of medieval age , whose stories and transformations r
# 1 ( string , length 254 ) , a precise age of every site ; – age_2 ( string , le
# length 254 ) , ages grouped in the 11 age ranges proposed by barker ( 1995 ) :
# eolithic ( 3000 bc-2000 bc ) , bronze age ( 2000 bc-1000 bc ) , iron age ( 1000
# bronze age ( 2000 bc-1000 bc ) , iron age ( 1000 bc-500 bc ) , samnite age ( 50
# iron age ( 1000 bc-500 bc ) , samnite age ( 500 bc-80 bc ) , roman age ( 80 bc-
#  samnite age ( 500 bc-80 bc ) , roman age ( 80 bc-600 bc ) , medieval age ( 600
# roman age ( 80 bc-600 bc ) , medieval age ( 600 ad-1500 ad ) , post-medieval ag
# ge ( 600 ad-1500 ad ) , post-medieval age ( 1500 ad-1800 ad ) , recent age ( 18
# eval age ( 1500 ad-1800 ad ) , recent age ( 1800 ad-present ) . 372 e. valente
# g all the archaeological sites in the age classes listed in the age_2 field of
# le . archaeological sites grouped for age have been then plotted on the 40 m mo
# rs above sea level ) respect the site age has been examined to verify a possibl
# ll archaeological sites with the same age and exported them in a new point shap
#  eneolithic ( fig . 7c ) , the bronze age ( fig . 7d ) and the iron age ( fig .
#  bronze age ( fig . 7d ) and the iron age ( fig . 7e ) , archaeological sites h
# tor of the study area during the iron age . archaeological sites of samnite age
# age . archaeological sites of samnite age ( fig . 7f ) are widespread all over
#  total , fig . 7k ) have an uncertain age and they have been mainly recognized
# tes archaeological sites of a precise age whereas black dots indicate archaeolo
# gical sites older than the considered age . we have also analysed site distribu
# e elevation as a function of the site age . it is possible to note that the min
# a local minimum during the eneolithic age ( median value around 190 m a.s.l. )
#  1300 m a.s.l . ( during the medieval age ) , with a local minimum during the e
# a local minimum during the eneolithic age ( maximum elevation around 880 m a.s.
# nd a local maximum during the samnite age ( maximum elevation close to 1400 m a
# tes from the palaeolithic to the iron age have been excluded from this analysis
# s ( 19 % of the 2786 sites ranging in age from the samnite to the recent time )
# , also counting 58 sites of uncertain age . all the site typologies listed in f
#  also including 45 sites of uncertain age . again , all the site typologies lis
# n ( m a.s.l . ) as a function of site age . moreover , this study provides a po
# , during the palaeolithic to the iron age time span , archaeological sites were
#  this period , and during the samnite age , humans started moving uphill , as i
#
#
# Concordance for '–':
# Displaying 32 of 32 matches:
#  according to the following workflow : – census of all known archaeological fin
# egion through bibliographic analysis . – implementation , for the first time ,
#  and updated archaeological database . – integration of this database into a ge
# in the molise region ( italy ) fig . 1 – some of the most relevant archaeologic
# onastery of san vincenzo al volturno . – generation of an updated computerized
# ows ( field type is in parentheses ) : – code ( string , length 10 ) that inclu
# ted followed by a progressive number ; – province ( string , length 20 ) , whic
# ere archaeological sites fall within ; – municipality ( string , length 50 ) ,
# nicipality where the site is located ; – locality ( string , length 50 ) and ad
# ther information about site location ; – reference system ( string , length 20
# e archaeological sites ( utm-wgs84 ) ; – z coord ( double , precision 0 , scale
# vation above sea level of every site ; – point x ( double , precision 0 , scale
# de of the plotted sites respectively ; – cartography ( string , length 20 ) tha
# or 1:25.000 scale topographic maps ) ; – number cart . ( string , length 20 ) t
# e number of the used topographic map ; – georeferencing method ( string , lengt
# c maps , field work or aerial photos ; – georeference quality ( string , length
# w much reliable the site location is ; – research method ( string , length 50 )
# ibliographic research and field work ; – description ( string , length 254 ) ,
# h have been subdivided in 19 classes ; – definition ( string , length 254 ) a b
# re detailed description of the sites ; – description_1 to description_5 ( strin
# ription of every archaeological site ; – age_1 ( string , length 254 ) , a prec
#  254 ) , a precise age of every site ; – age_2 ( string , length 254 ) , ages g
# sent ) . 372 e. valente , m. cozzolino – references ( string , length 254 ) , b
#  only 6 archaeological sites . fig . 2 – spatial distribution of the mapped arc
#  374 e. valente , m. cozzolino fig . 3 – map of the archaeological sites for al
# in the molise region ( italy ) fig . 4 – map of the archaeological sites for al
#  376 e. valente , m. cozzolino fig . 5 – map of the archaeological sites for al
# in the molise region ( italy ) fig . 6 – density map of the archaeological site
#  378 e. valente , m. cozzolino fig . 7 – chronological distribution of the arch
#  380 e. valente , m. cozzolino fig . 9 – percentage of archaeological site typo
# ct to the total mapped sites . fig . 8 – box plot of the site elevation ( m a.s
# orthy to note that , anyway , fig . 10 – a ) white dots indicate archaeological
#
#
# Concordance for 'del':
# Displaying 31 of 31 matches:
# no ( grotta reali site ) , civitanova del sannio ( morricone del pesco site ) ,
# ) , civitanova del sannio ( morricone del pesco site ) , cerro al volturno ( mo
#  , bonefro , casacalenda , castellino del biferno , colletorto , montelongo , m
# ngo , montorio dei frentani , morrone del sannio , provvidenti , ripabottoni ,
# 015 ; amato et al . 2016 ) , belmonte del sannio , agnone , capracotta , vastog
# cipality of castropignano and torella del sannio to the n and of bojano , san p
#  , vinchiaturo ( 44 sites ) , morrone del sannio ( 43 sites ) , san martino in
# sociali e della formazione università del molise marilena.cozzolino @ unimol.it
#  rotili ( eds . ) , la trasformazione del mondo romano e le grandi migrazioni .
# rionale e centro-orientale alle coste del mediterraneo . atti del convegno inte
# le alle coste del mediterraneo . atti del convegno internazionale di studi ( ci
# enti alle antichità e alle belle arti del molise , 5 , campobasso , 16-17. de b
# ituto regionale per gli studi storici del molise . de tata p. 1990 , l ’ anfite
# iro ( eds . ) , samnium . archeologia del molise , catalogo della mostra , roma
#  santone m. , santoro w. 2010 , carta del rischio archeologico nell ’ area del
#  del rischio archeologico nell ’ area del cratere . primi dati di survey nei co
# i survey nei comuni colpiti dal sisma del 2002 , campobasso , soprintendenza pe
# oprintendenza per i beni archeologici del molise . di rocco g. 2009 , castelli
# edievale 10 , firenze , all ’ insegna del giglio . djindjian f. 1998 , gis usag
# 2005 , nuove ricerche sul paleolitico del molise . materie prime , industrie li
# ante e il sannio antico , « almanacco del molise » , 161-208. lippolis e. , gui
#  2015 , larino : ricerche nell ’ area del foro , « scienze dell ’ antichità » ,
#  , pesino c. 2003 , guida ai castelli del molise , pescara , carsa edizioni . m
# contri e suggestioni lungo i tratturi del molise , cerro al volturno , volturni
# eistoria in molise . gli insediamenti del territorio di isernia , roma , aracne
# frentani dal vi al i secolo a.c. atti del convegno ( isernia 1980 ) , campobass
# 007 , geografia e storia dei tratturi del mezzogiorno , roma , aracne . peretto
# te sulla preistoria dell ’ alta valle del volturno , in a. testa ( ed . ) , l ’
# azia di san vincenzo e l ’ alta valle del volturno , « archeomolise » , 3 , 8 ,
# ta archeologica dei territori montani del sannio pentro nord-occidentale , tesi
# 0 , atlante delle emergenze culturali del molise . risultati , riflessioni ed i
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Specify the file path where you want to save the text file
file_path = "output.txt"

# Open the file in write mode ('w') and write the content to it
with open(file_path, "w", encoding="utf-8") as text_file:
    text_file.write(abstracts_as_text)

print("Text saved to", file_path)
# Out:
# Text saved to output.txt

# %%
#Now let's restart the process with the next text file: output.txt

import nltk

# tokenization is the process of splitting strings into their individual "tokens"
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

# to import a .txt file we use the "open" function, giving it the path to our text file and an instrution about what we want to do with the file
# here, we would like to "read" our file into a variable so 
transcript = open('output.txt', encoding='utf-8').read().lower()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# we could then tokenize by sentence, which splits the text into sentences
transcript_sentences = sent_tokenize(transcript)
transcript_sentences
# Out:
# ["abella \nabellinum\nacerrae\naceruntia \naecae\naeclanum\naefula\naequana\naequum tuticum\naesernia\nafilae\nalba fucens\nalbano di lucania\naletrium\nallifae\nalsium\naltamura\nameria\namiternum\namyclae\nanagnia\nangitiae lucus \nangulum\nantemnae\nantinum \nantium\nanxanum \nanxia\naquilonia\naquinum\narcipete \nardea\naricia\narpi \narpinum\nartena\natella\naternum \natina\natina\naufidena\naufinum\nausculum\naveia\naxia\nbagnoregio\nbantia\nbaragiano\nbarduli\nbarium\nbellegra\nbeneventum \nblera\nbovianum \nbovillae\nbuon riposo\nbutuntum \ncaelia1\ncaere \ncaiatia\ncalatia\ncales\ncallifae\ncampo del pozzo\ncamporosso\ncannae\ncanusium\ncapena\ncapua\ncarseoli \ncarsulae\ncasalini sottana\ncasilinum\ncasinum\ncastel canonico\ncastellina\ncastello monteforte\ncastellone\ncastrimoenium\ncastrum inui\ncastrum novum1\ncaudium\ncencelle\ncentum cellae\ncereatae marianae\ncesoli\ncima ramne\ncirceii \ncivita danzica\ncivita del fosso d'arlena\ncivita delle bianche\ncivita di tricarico\ncivitanova \ncivitella1\ncivitella2 \ncliternia\ncluviae\ncollatia\ncolle arienzo \ncolle cavallo\ncolle della battaglia\ncolle delle fate\ncolle delle spugne\ncolle d'onofrio\ncolle marena \ncolle mitra\ncolle rischia\ncolle rotondo\ncolle santa lucia-colle maceralonga\ncolle sant'angelo\ncolle separa\ncompsa\ncora\ncorchiano\ncorcolle\ncorfinium\ncozzo presepe\ncroccia cognato\ncubulteria \ncumae \ncupola\ncures\ncurino\ndifesa san biagio\nduronia \neburum\neretum\nfabrateria nova\nfabrateria vetus  \nfagifulae\nfalerii novi\nfalerii veteres\nferentinum \nferentium \nferrazzano\nfescennium\nficana\nficulea\nfidenae\nfioccaglia di flumeri\nforcona\nforentum\nformiae\nforum appii\nforum cassii\nforum claudii\nforum clodii\nforum novum1\nforum popili\nforum popillii\nfosso camponi\nfratte\nfregellae\nfregenae\nfrigento\nfrusino\nfundi\nfurfo\ngabii\ngallese\ngenusia\nginosa\ngraviscae\ngrotta porciosa\nhatria \nherculaneum \nherdoniae \nhistonium\nhorta\nhortona \ninteramna lirenas  \ninteramna nahars\niuvanum\nla giostra\nla giurlanda\nla rocca1\nla rocca2\nla romana\nlanuvium\nlarinum\nlavinium\nle murella\nlecce vecchio\nligures baebiani \nliternum\nluceria \nlucus feroniae \nluni sul mignone\nmagliano sabina\nmaratta bassa\nmarruvium\nmesula \nminturnae\nmisenum\nmontagna di gildone\nmonte acero\nmonte alifano\nmonte boscone\nmonte casoli\nmonte castellone1\nmonte castellone2\nmonte castellone3\nmonte cavallerizzo\nmonte cila\nmonte civitella\nmonte crocella\nmonte decoro\nmonte di cerro\nmonte ferrante\nmonte frontino\nmonte irsi\nmonte miglio\nmonte nero\nmonte praticelle\nmonte pugliano\nmonte rocca l'abate\nmonte rovello\nmonte san felice \nmonte san giovanni\nmonte san nicola1\nmonte san nicola2\nmonte san nicola3\nmonte san paolo\nmonte santa croce1\nmonte santa croce2\nmonte santa croce3\nmonte santa croce4\nmonte santa trinit?",
#  "monte sant'angelo \nmonte sant'angelo palomba\nmonte sant'antonio\nmonte saraceno di cercemaggiore\nmonte urano\nmonte vairano\nmontenerodomo\nmonterano\nmontescaglioso\nmontrone\nmorcone\nmusarna\nnarnia \nnazzano romano\nneapolis \nnepet \nnersae\nnola\nnomentum\nnorba1\nnuceria1\nocriculum\nolevano romano\noppidovetere \norcla \nortona dei marsi\nostia\npaestum\npallanum\npantaleno\nparthenope\npeltuinum\npinna vestinorum\npoggio castelsecco\npoggio evangelista\npomarico vecchio\npompeii\npontecagnano\npotentia1\npraeneste\nprivernum\npunta penna\nputeoli \npyrgi\nquota 1052m\nraia san basile\nreate\nrocca vecchia\nrocca1\nrocca2\nroccasecca\nroma\nrotale\nrotella di collalto\nrubi\nrufrae \nrupecanina\nsaepinum\nsalapia \nsalapia vetus\nsalernum \nsan giovenale\nsan giuliano\nsan pasquale\nsan salvatore\nsanta maria dei vignali\nsant'eustachio\nsanto mola\nsaticula \nsatricum\nselva del monaco\nserra del carpine\nserra di cedro\nserra di fagato\nserra di vaglio\nserra guardiola\nserro dell'incoronata\nsetia\nsignia\nsilvium \nsinuessa \nsipontum \nsora\nsorrina \nstabiae\nstatonia\nsuessa aurunca\nsuessula\nsulmo\nsuperaequum\nsurrentum\nsutrium\ntarquinia \ntarracina \nteanum apulum\nteanum sidicinum\nteate\ntelesia\ntempa san nicola\nterravecchia di sepino\nterventum\ntibur\ntoppa santa barbara\ntorre di satriano\ntorre d'ischia\ntorretta\ntreba\ntrebula\ntrebula balliniensium \ntrebula mutuesca \ntrebula suffenas \ntuscana\ntusculum\nvallo di san nicola\nvaria\nveii\nvelitrae\nvenafrum\nvenusia\nverulae\nvibinum \nvicalvi\nvico\nvignanello\nvisentium\nvolcei\nvolsinii\nvolturnum\nvulci"]

# %%
# now remember that huge block of stopwords manually typed out in the sample block of code from the first lesson? That comes built in to NLTK as you may have guessed from the earlier import statment
# we can assign the NLTK stopwords to a variable like so:
stop_words = stopwords.words('english')

# and then remove the stopwords from out text using a loop to check if each word in the transcript and only keep the words that are NOT in out stopword list
filtered_transcript_words = []
for word in transcript_words:
    if word not in stop_words:
        filtered_transcript_words.append(word)

# %%
# finally, we can simply find word frequeny with NLTK's frequnecy distribution function
from nltk import FreqDist

transcript_fdist = FreqDist(filtered_transcript_words)
transcript_fdist.most_common(20)
# Out:
# [(',', 643),
#  ('.', 305),
#  (')', 187),
#  ('(', 181),
#  ('archaeological', 128),
#  ('sites', 126),
#  ('molise', 78),
#  ('region', 63),
#  (';', 56),
#  ('site', 51),
#  ('di', 49),
#  ('fig', 42),
#  ('age', 35),
#  ('–', 32),
#  ('del', 31),
#  ('gis', 28),
#  ('m.', 28),
#  ('e', 26),
#  ('de', 22),
#  ('italy', 21)]

# %%
# now, as you can see, our list is topped by punctuation and contractions!

# to remove punctuation, we can use Python's string library to create a list of punctuation
from string import punctuation
punctuation = list(punctuation)

# and luckily, you can modify your stopwords and punctuation lists like any other list!
# let's add "n't", "'s", and "would"
# to add multiple elements to a list at once, we use extend() rather that append()
stop_words.extend(["n't", "'s", 'would'])

# %%
# let's re-run with our new stopwords and punctuation list to see the improved results
filtered_transcript_words = []
for word in transcript_words:
    if word not in stop_words and word not in punctuation:
        filtered_transcript_words.append(word)

transcript_fdist = FreqDist(filtered_transcript_words)
transcript_fdist.most_common(10)
# Out:
# [('archaeological', 128),
#  ('sites', 126),
#  ('molise', 78),
#  ('region', 63),
#  ('site', 51),
#  ('di', 49),
#  ('fig', 42),
#  ('age', 35),
#  ('–', 32),
#  ('del', 31)]

# %%
text_list = Text(transcript_words)

# Get the 10 most common words
common_words = [word for word, _ in transcript_fdist.most_common(10)]

# Loop through the common words and get concordance for each
for word in common_words:
    print(f"Concordance for '{word}':")
    text_list.concordance(word, lines=52)
    print("\n")
# Out:
# Concordance for 'archaeological':
# Displaying 52 of 128 matches:
# 19 , 367-385 gis mapping of the archaeological sites in the molise region ( it
#  as it is testified by its rich archaeological and architectural heritage ( de
# toric times , the most relevant archaeological findings can be chronologically
#  and volumes published for each archaeological site , without considering the
# oth the superintendency for the archaeological heritage of the molise region a
# emic teams carried out numerous archaeological excavations and explorations in
# ise region . as a result , some archaeological contexts can now rely on a rich
# tematic study . moreover , many archaeological materials derived from emergenc
# dardize and store the myriad of archaeological data from the molise region , f
# orkflow : – census of all known archaeological findings of the molise region t
# ime , of a detailed and updated archaeological database . – integration of thi
# c maps . 369 gis mapping of the archaeological sites in the molise region ( it
# . 1 – some of the most relevant archaeological sites in the molise region . a
# updated computerized map of the archaeological evidences of the study area as
# useful for the promotion of the archaeological heritage and a tool for more su
#  that include the collection of archaeological data , the collection of topogr
# al analysis . 2.1 collection of archaeological data the collection of a large
# of a large amount of data about archaeological sites within the molise region
# gation , published detail scale archaeological researches carried out by both
# ntists have been analysed . the archaeological maps realized in the municipali
# wn data related to detail scale archaeological surveys . the monographs of the
# verviews on the distribution of archaeological sites during specific time span
# que attempt to take a census of archaeological sites in the molise region , re
# classical sites , 73 industrial archaeological remnants , 31 sites belonging t
#  an unprecedented collection of archaeological data in the frame of the projec
# sulted in the collection of 905 archaeological sites in the entire region . in
# tire region . in addition , 977 archaeological data collected by barker ( 1995
# r database . as a result , 1882 archaeological sites have been collected durin
# stigation , the archives of the archaeological superintendence have been analy
# ly , new and inedited data from archaeological impact assessment reports ( rel
# tigation led us to collect 3111 archaeological sites within the entire molise
# base creation all the collected archaeological sites have been listed in a poi
# eviously 371 gis mapping of the archaeological sites in the molise region ( it
# . the point shapefile , named “ archaeological sites ” , includes several fiel
# r isernia or campobasso ) where archaeological sites fall within ; – municipal
# erence system used to geolocate archaeological sites ( utm-wgs84 ) ; – z coord
# ographic map used to locate the archaeological site ( either 1:5000 or 1:25.00
# the method used to locate every archaeological site , either by web research ,
# irst , brief description of the archaeological sites , which have been subdivi
# d detailed description of every archaeological site ; – age_1 ( string , lengt
# b references where every single archaeological site has been derived from . 2.
# al analysis all the 3111 listed archaeological sites have been then analysed i
# en analysed by grouping all the archaeological sites in the age classes listed
# ted in the age_2 field of the “ archaeological site ” shapefile . archaeologic
# chaeological site ” shapefile . archaeological sites grouped for age have been
# his case , we have selected all archaeological sites with the same age and exp
# the value field . finally , the archaeological sites spatial distribution and
# le . we have then clipped the “ archaeological site ” shapefile with this buff
# ribution of all the 3111 mapped archaeological sites of the molise region is r
# reported in fig . 2. moreover , archaeological sites have been plotted on a 40
# san polo 373 gis mapping of the archaeological sites in the molise region ( it
# ality has the largest number of archaeological sites within its territory , wi
#
#
# Concordance for 'sites':
# Displaying 52 of 126 matches:
# 85 gis mapping of the archaeological sites in the molise region ( italy ) 1. in
# more recent and relevant prehistoric sites have been also found in the municipa
# i ( piana s. mauro and fonte curello sites ) , rocchetta a volturno ( grotta re
# 69 gis mapping of the archaeological sites in the molise region ( italy ) fig .
#  of the most relevant archaeological sites in the molise region . a ) remains o
#  amount of data about archaeological sites within the molise region has been ca
# akley 1995 ) and of the palaeolithic sites in molise ( grimaldi 2005 ) gave als
# n the distribution of archaeological sites during specific time span . the atla
# t to take a census of archaeological sites in the molise region , resulting in
# , resulting in the collection of 228 sites ( 124 classical sites , 73 industria
# lection of 228 sites ( 124 classical sites , 73 industrial archaeological remna
# ustrial archaeological remnants , 31 sites belonging to various categories ) .
# the collection of 905 archaeological sites in the entire region . in addition ,
#  . as a result , 1882 archaeological sites have been collected during this firs
# ed us to collect 3111 archaeological sites within the entire molise region . 2.
# ion all the collected archaeological sites have been listed in a point shapefil
# 71 gis mapping of the archaeological sites in the molise region ( italy ) menti
# t shapefile , named “ archaeological sites ” , includes several fields that hav
# or campobasso ) where archaeological sites fall within ; – municipality ( strin
# tem used to geolocate archaeological sites ( utm-wgs84 ) ; – z coord ( double ,
# ongitude and latitude of the plotted sites respectively ; – cartography ( strin
# ef description of the archaeological sites , which have been subdivided in 19 c
# f , more detailed description of the sites ; – description_1 to description_5 (
# s all the 3111 listed archaeological sites have been then analysed in a gis sof
# the areal distribution of the mapped sites , we performed a density analysis tr
# d by grouping all the archaeological sites in the age classes listed in the age
# al site ” shapefile . archaeological sites grouped for age have been then plott
# amined to verify a possible trend in sites distribution through time . in this
#  we have selected all archaeological sites with the same age and exported them
# field . finally , the archaeological sites spatial distribution and its relatio
# buffer and we have extracted all the sites located within 1000 m from both the
# f all the 3111 mapped archaeological sites of the molise region is reported in
# n fig . 2. moreover , archaeological sites have been plotted on a 40 m dtm of t
# unicipalities of the molise region . sites distribution enhances the occurrence
# 73 gis mapping of the archaeological sites in the molise region ( italy ) mates
# the largest number of archaeological sites within its territory , with 277 mapp
# thin its territory , with 277 mapped sites ( fig . 3a ) . it is followed by cas
#  it is followed by casacalenda ( 186 sites , fig . 3b ) , isernia ( 167 sites ,
# 6 sites , fig . 3b ) , isernia ( 167 sites , fig . 4a ) , guglionesi ( 162 site
# ites , fig . 4a ) , guglionesi ( 162 sites , fig . 4b ) , trivento ( 106 sites
#  sites , fig . 4b ) , trivento ( 106 sites , fig . 5a ) and campomarino ( 102 s
# s , fig . 5a ) and campomarino ( 102 sites , fig . 5b ) , that are the only mun
# es with more than 100 archaeological sites . other municipalities with a releva
#  a relevant number of archaeological sites are venafro ( 98 sites ) , agnone (
# rchaeological sites are venafro ( 98 sites ) , agnone ( 66 sites ) , termoli (
# e venafro ( 98 sites ) , agnone ( 66 sites ) , termoli ( 65 sites ) , castropig
# , agnone ( 66 sites ) , termoli ( 65 sites ) , castropignano ( 61 sites ) , bar
# li ( 65 sites ) , castropignano ( 61 sites ) , baranello ( 53 sites ) , macchia
# ignano ( 61 sites ) , baranello ( 53 sites ) , macchia valfortore ( 49 sites )
# 53 sites ) , macchia valfortore ( 49 sites ) , colle d ’ anchise and guardialfi
# e d ’ anchise and guardialfiera ( 46 sites ) , vinchiaturo ( 44 sites ) , morro
# iera ( 46 sites ) , vinchiaturo ( 44 sites ) , morrone del sannio ( 43 sites )
#
#
# Concordance for 'molise':
# Displaying 52 of 78 matches:
#  of the archaeological sites in the molise region ( italy ) 1. introduction th
# egion ( italy ) 1. introduction the molise region is in the northern sector of
#  ) 1 . the oldest human presence in molise is represented by the upper palaeol
# he highest topographic peaks of the molise region . these fortifications were
# n findings are evenly widespread in molise , and the city of saepinum ( fig .
# ns represent important pages of the molise history ( marino , carnevale , pesi
#  the archaeological heritage of the molise region and different national and i
# ions and explorations in the entire molise region . as a result , some archaeo
# iad of archaeological data from the molise region , from 2013 until present ,
# aboration between the university of molise , the regional directorate of cultu
# directorate of cultural heritage of molise and the administrative division of
#  and the administrative division of molise has led to undertake significant ac
# nown archaeological findings of the molise region through bibliographic analys
#  of the archaeological sites in the molise region ( italy ) fig . 1 – some of
# elevant archaeological sites in the molise region . a ) remains of pietrabbond
# out archaeological sites within the molise region has been carried out through
#  ) and of the palaeolithic sites in molise ( grimaldi 2005 ) gave also importa
# he atlas of cultural emergencies of molise ( zilli 2010 ) , edited by universi
# li 2010 ) , edited by university of molise , has been also analysed ; the latt
# nsus of archaeological sites in the molise region , resulting in the collectio
# d by the administrative division of molise . this project resulted in the coll
# directorate of cultural heritage of molise . consequently , new and inedited d
# haeological sites within the entire molise region . 2.2 collection of topograp
# scale 1:5000 ( technical map of the molise region ) and 1:25.000 ( i.g.m . top
# ble by the technical offices of the molise region . in addition , a 40 m dtm o
# n . in addition , a 40 m dtm of the molise region has been used . 2.3 gis data
#  of the archaeological sites in the molise region ( italy ) mentioned topograp
# ed topographic maps and on the 40 m molise dtm . the point shapefile , named “
#  have been then plotted on the 40 m molise dtm . furthermore , site elevation
#  mapped archaeological sites of the molise region is reported in fig . 2. more
# e been plotted on a 40 m dtm of the molise region together with a polyline sha
# rs of all the municipalities of the molise region . sites distribution enhance
#  of the archaeological sites in the molise region ( italy ) matese and campoch
# venafro to the sw. among the entire molise region , the larino municipality ha
# is the administrative centre of the molise region and the most populated town
# ites , plotted on a 40 m dtm of the molise region . black dots indicate the ar
# rs of all the municipalities of the molise region . 374 e. valente , m. cozzol
# ocated in the central sector of the molise region . furthermore , the analysis
#  of the archaeological sites in the molise region ( italy ) fig . 4 – map of t
# n and in the eastern sectors of the molise region , corresponding to the munic
#  the venafro plain ) sectors of the molise region , with sparse sporadic sites
#  of the archaeological sites in the molise region ( italy ) fig . 6 – density
#  of the archaeological sites of the molise region . the same areas resulted to
# dings in the central portion of the molise region and in the medium biferno ri
#  the central-western portion of the molise region . 378 e. valente , m. cozzol
#  of the archaeological sites in the molise region . white dots indicates archa
#  of the archaeological sites in the molise region ( italy ) palaeolithic ( med
# o analyse human distribution in the molise region . it represents , up to now
#  of the archaeological sites in the molise region ( italy ) correspondence of
# ey and in the central sector of the molise region . in addition , they were lo
#  of archaeological sites within the molise region and the gis analysis carried
#  the archaeological heritage of the molise region worldwide and to address urb
#
#
# Concordance for 'region':
# Displaying 52 of 63 matches:
#  archaeological sites in the molise region ( italy ) 1. introduction the molis
#  italy ) 1. introduction the molise region is in the northern sector of southe
# est topographic peaks of the molise region . these fortifications were built w
# e romans , who dominated the entire region in the period between the i century
# chaeological heritage of the molise region and different national and internat
# d explorations in the entire molise region . as a result , some archaeological
# archaeological data from the molise region , from 2013 until present , a fruit
# chaeological findings of the molise region through bibliographic analysis . –
#  archaeological sites in the molise region ( italy ) fig . 1 – some of the mos
#  archaeological sites in the molise region . a ) remains of pietrabbondante ;
# haeological sites within the molise region has been carried out through a two
#  archaeological sites in the molise region , resulting in the collection of 22
#  archaeological sites in the entire region . in addition , 977 archaeological
# ical sites within the entire molise region . 2.2 collection of topographic dat
# :5000 ( technical map of the molise region ) and 1:25.000 ( i.g.m . topographi
# the technical offices of the molise region . in addition , a 40 m dtm of the m
# addition , a 40 m dtm of the molise region has been used . 2.3 gis database cr
#  archaeological sites in the molise region ( italy ) mentioned topographic map
#  archaeological sites of the molise region is reported in fig . 2. moreover ,
# plotted on a 40 m dtm of the molise region together with a polyline shapefile
# ll the municipalities of the molise region . sites distribution enhances the o
# al and south-western sectors of the region . the north-eastern cluster is ne-s
#  archaeological sites in the molise region ( italy ) matese and campochiaro to
#  to the sw. among the entire molise region , the larino municipality has the l
# administrative centre of the molise region and the most populated town of the
# e most populated town of the entire region ( 49320 inhabitants ) , is characte
# plotted on a 40 m dtm of the molise region . black dots indicate the archaeolo
# ll the municipalities of the molise region . 374 e. valente , m. cozzolino fig
# in the central sector of the molise region . furthermore , the analysis 375 gi
#  archaeological sites in the molise region ( italy ) fig . 4 – map of the arch
# n the eastern sectors of the molise region , corresponding to the municipaliti
# nafro plain ) sectors of the molise region , with sparse sporadic sites in the
# sites in the central portion of the region . 377 gis mapping of the archaeolog
#  archaeological sites in the molise region ( italy ) fig . 6 – density map of
#  archaeological sites of the molise region . the same areas resulted to be occ
# n the central portion of the molise region and in the medium biferno river val
# y and in the central portion of the region . on the opposite , they were compl
# cking in the western portion of the region , with the only exception of few sp
# areas in the central portion of the region with some samnite finds . the same
# man finds distributed in the entire region and mirroring the three main cluste
# y and in the central portion of the region ( fig . 7h ) . on the opposite , po
# y and in the central portion of the region , being completely lacking in the r
# mpletely lacking in the rest of the region ( fig . 7i ) . recent archaeologica
# ntral-western portion of the molise region . 378 e. valente , m. cozzolino fig
#  archaeological sites in the molise region . white dots indicates archaeologic
#  archaeological sites in the molise region ( italy ) palaeolithic ( median val
# se human distribution in the molise region . it represents , up to now , the l
# ed sites , widespread in the entire region , with three main clusters located
# in the south-western sectors of the region , respectively . moreover , the hig
#  archaeological sites in the molise region ( italy ) correspondence of the his
# in the central sector of the molise region . in addition , they were located a
# geneously distributed in the entire region . in this period , and during the s
#
#
# Concordance for 'site':
# Displaying 51 of 51 matches:
# nd references ; peretto 2013 ) . the site represents a unique example in the h
# lities of pescopennataro ( rio verde site ) , carovilli ( piana s. mauro and f
#  rocchetta a volturno ( grotta reali site ) , civitanova del sannio ( morricon
# ova del sannio ( morricone del pesco site ) , cerro al volturno ( monte s. cro
# , cerro al volturno ( monte s. croce site ) and in the biferno valley ( barker
# es published for each archaeological site , without considering the large amou
# accurate description of every single site . moreover , fields have been named
# e name of the municipality where the site is located followed by a progressive
# e name of the municipality where the site is located ; – locality ( string , l
# at provide further information about site location ; – reference system ( stri
# e elevation above sea level of every site ; – point x ( double , precision 0 ,
# ap used to locate the archaeological site ( either 1:5000 or 1:25.000 scale to
#  used to locate every archaeological site , either by web research , satellite
# ain , based on how much reliable the site location is ; – research method ( st
# ethod used to recognize every single site , including web research , bibliogra
#  description of every archaeological site ; – age_1 ( string , length 254 ) ,
# ength 254 ) , a precise age of every site ; – age_2 ( string , length 254 ) ,
# es where every single archaeological site has been derived from . 2.4 gis spat
# densities ; method = planar . then , site distribution during different ages h
#  age_2 field of the “ archaeological site ” shapefile . archaeological sites g
#  the 40 m molise dtm . furthermore , site elevation ( expressed in meters abov
# meters above sea level ) respect the site age has been examined to verify a po
# ithin the table of attribute , using site elevation as the value field . final
# ve then clipped the “ archaeological site ” shapefile with this buffer and we
# es have been classified according to site typology of the “ description ” fiel
# tion ” field of the “ archaeological site ” shapefiles ( see material and meth
# een obtained . in addition , maximum site density values of 21 sites/km² and 1
# es have been classified according to site typology of the “ description ” fiel
# tion ” field of the “ archaeological site ” shapefiles ( see material and meth
# es have been classified according to site typology of the “ description ” fiel
# tion ” field of the “ archaeological site ” shapefiles ( see material and meth
# nsidered age . we have also analysed site distribution as a function of the si
# te distribution as a function of the site elevation ( expressed in meters abov
#  fig . 8 we report a box plot of the site elevation as a function of the site
#  site elevation as a function of the site age . it is possible to note that th
# is possible to note that the minimum site elevation is almost constant during
# a.s.l. ) . a decreasing trend of the site elevation has been recognized from t
# tion ” field of the “ archaeological site ” shapefiles described in the materi
# ection . moreover , the most diffuse site type is the archaeological finds gro
# lysed a possible correlation between site location and some either man-made (
#  58 sites of uncertain age . all the site typologies listed in fig . 9 fall wi
# s of uncertain age . again , all the site typologies listed in fig . 9 fall wi
# g . 9 – percentage of archaeological site typology respect to the total mapped
# ed sites . fig . 8 – box plot of the site elevation ( m a.s.l . ) as a functio
# ation ( m a.s.l . ) as a function of site age . moreover , this study provides
# cal finds , whereas the most diffuse site typologies , that reflect the occurr
#  la pineta , a new lower paleolithic site in central italy , « nature » , 300
#  isernia la pineta lower paleolithic site , molise , italy , « quaternary inte
# n presence since prehistoric times . site distribution is not homogeneous thro
# ( 12.9 % ) and buildings ( 9.8 % ) . site distribution is mainly clustered alo
# , with a general increasing trend of site elevation through time . this gis da
#
#
# Concordance for 'di':
# Displaying 49 of 49 matches:
# .vv . 1980 ; pellicano 2007 ; meini , di felice , petrella 2018 ; minotti et a
#  , the fortifications of terravecchia di sepino ( matteini chiari , gaggiotti
# rences ) and larinum ( de tata 1990 ; di niro 1991 ; caliò , lepone , lippolis
#  ( marino , carnevale , pesino 2003 ; di rocco 2009 ) . in the last years , bo
# ti , ripabottoni , rotello , s. croce di magliano , s. giuliano di puglia , ur
#  , s. croce di magliano , s. giuliano di puglia , ururi ( di niro , santone ,
# ano , s. giuliano di puglia , ururi ( di niro , santone , santoro 2010 ) , ise
# years . ettore valente * dipartimento di scienze della terra , dell ’ ambiente
#  delle risorse università degli studi di napoli federico ii ettore.valente @ u
# na.it marilena cozzolino dipartimento di scienze umanistiche , sociali e della
# . , cozzolino m. , de benedittis g. , di paola g. , gentile v. , giordano c. ,
# a ) : il teatro romano , « bollettino di archeologia » , 229-232. capini s. ,
# ia v. 1988 , lo scavo della necropoli di vicenne , « conoscenze » , 4 , 31-48.
# 0 , campochiaro ( cb ) . la necropoli di vicenne , in e. arslan , m. buora ( e
#  idrico e fognante , « considerazioni di storia e archeo- logia » , 8 , 23-32.
# i . 2012 , nuovi dati dalla necropoli di vicenne a campochiaro , in c. ebanist
# eo . atti del convegno internazionale di studi ( cimitile-santa maria capua ve
# 1-22. conventi m. 2004 , città romane di fondazione , roma , l ’ erma di brets
# omane di fondazione , roma , l ’ erma di bretschneider . de benedittis g. 1974
# edittis g. 1974 , il centro sannitico di monte vairano presso campobasso , in
# no presso campobasso , in docu- menti di antichità italiche e romane . soprint
#  ed il suo territorio : primi appunti di topografia storica , isernia , lavegl
# tis g. 1988 , monte vairano , la casa di “ ln ” , catalogo della mostra , camp
# edittis g. 2008 , molise : esperienze di survey : riccia , oratino , castropig
#  tata p. 1990 , l ’ anfiteatro romano di larinum : le campagne di scavo 1987-1
# eatro romano di larinum : le campagne di scavo 1987-1988 , « cono- scenze » ,
# 9-137 . 384 e. valente , m. cozzolino di niro a . 1991 , larinum , in s. capin
#  . 1991 , larinum , in s. capini , a. di niro ( eds . ) , samnium . archeologi
# lla mostra , roma , quasar , 263-267. di niro a. , santone m. , santoro w. 201
#  nell ’ area del cratere . primi dati di survey nei comuni colpiti dal sisma d
#  per i beni archeologici del molise . di rocco g. 2009 , castelli e borghi mur
# castelli e borghi murati della contea di molise ( secoli x-xiv ) , quaderni di
# di molise ( secoli x-xiv ) , quaderni di archeologia medievale 10 , firenze ,
# sediamenti , isernia , centro europeo di ricerche preistoriche . la regina a .
# o- basso , edizioni enne . meini m. , di felice g. , petrella m. 2018 , geotou
# ise . gli insediamenti del territorio di isernia , roma , aracne editrice . mi
# editrice . minotti m. , giancola c. , di marzio p. , di martino p. 2018 , land
# tti m. , giancola c. , di marzio p. , di martino p. 2018 , land use dynamics o
# e roads : the case of tratturo castel di sangro-lucera ( molise , italy ) , «
# el j.p. 1984 , il santuario sannitico di vastogirardi . resoconto degli scavi
# i e degli scavi nel santuario italico di vastogirardi ( is ) , in d. caiazza (
# ed . ) , italica ars . studi in onore di giovanni colonna per il premio i sann
# he in campania . fascicolo 5 : comune di venafro , roma , atlante tematico di
#  di venafro , roma , atlante tematico di topografia antica , suppl . xv . rufo
#  , in a. testa ( ed . ) , l ’ abbazia di san vincenzo e l ’ alta valle del vol
# sannio pentro nord-occidentale , tesi di dottorato , seconda università degli
# rato , seconda università degli studi di napoli . stek t.d . 2010 , cult place
# cavo archeologico della cinta muraria di aesernia , « fold & r . fasti on line
# sultati , riflessioni ed implicazioni di un primo censimento , campobasso , pa
#
#
# Concordance for 'fig':
# Displaying 42 of 42 matches:
#  ) . the remains of pietrabbondante ( fig . 1 a ) ( capini , de benedittis 2000
# n molise , and the city of saepinum ( fig . 1 b ) is considered the symbol of t
#  important roman towns are aesernia ( fig . 1 c ) ( catalano , paone , terzani
# nastery of san vincenzo al volturno ( fig . 1 d ) ( marazzi , delogu 1996 ; pao
#  sites in the molise region ( italy ) fig . 1 – some of the most relevant archa
# s of the molise region is reported in fig . 2. moreover , archaeological sites
# s territory , with 277 mapped sites ( fig . 3a ) . it is followed by casacalend
# followed by casacalenda ( 186 sites , fig . 3b ) , isernia ( 167 sites , fig .
#  , fig . 3b ) , isernia ( 167 sites , fig . 4a ) , guglionesi ( 162 sites , fig
# fig . 4a ) , guglionesi ( 162 sites , fig . 4b ) , trivento ( 106 sites , fig .
# , fig . 4b ) , trivento ( 106 sites , fig . 5a ) and campomarino ( 102 sites ,
#  . 5a ) and campomarino ( 102 sites , fig . 5b ) , that are the only municipali
# ence of only 6 archaeological sites . fig . 2 – spatial distribution of the map
# egion . 374 e. valente , m. cozzolino fig . 3 – map of the archaeological sites
# ological sites for square-kilometre ( fig . 6 ) . the analysis confirms the occ
#  sites in the molise region ( italy ) fig . 4 – map of the archaeological sites
# l sites 376 e. valente , m. cozzolino fig . 5 – map of the archaeological sites
# n one map . during the palaeolithic ( fig . 7a ) archaeological sites were main
#  sites in the molise region ( italy ) fig . 6 – density map of the archaeologic
#  in the medium biferno river valley ( fig . 7b ) . during the eneolithic ( fig
#  fig . 7b ) . during the eneolithic ( fig . 7c ) , the bronze age ( fig . 7d )
# ithic ( fig . 7c ) , the bronze age ( fig . 7d ) and the iron age ( fig . 7e )
# e age ( fig . 7d ) and the iron age ( fig . 7e ) , archaeological sites have be
# archaeological sites of samnite age ( fig . 7f ) are widespread all over the en
# same occurred during the roman time ( fig . 7g ) , with roman finds distributed
# the three main clusters recognized in fig . 1. medieval finds are spread in the
# n the central portion of the region ( fig . 7h ) . on the opposite , post-medie
# y lacking in the rest of the region ( fig . 7i ) . recent archaeological finds
#  7i ) . recent archaeological finds ( fig . 7j ) are very few with a random dis
# lly , 372 sites ( 12 % of the total , fig . 7k ) have an uncertain age and they
# egion . 378 e. valente , m. cozzolino fig . 7 – chronological distribution of t
# or if any correlation is present . in fig . 8 we report a box plot of the site
# ( dotted line within each box plot of fig . 8 ) highlight the occurrence of an
# y of archaeological finds is shown in fig . 9. type groups are those included i
# ( river ) features of the landscape ( fig . 10 ) . archaeological sites located
# 0 m from the tratturi are reported in fig . 10a . as tratturi appeared during t
# e . all the site typologies listed in fig . 9 fall within this buffer . in addi
# 00 m from main rivers are reported in fig . 10b . it includes 399 sites ( 13 %
# n , all the site typologies listed in fig . 9 fall within this buffer . 4. disc
# 006 ) . 380 e. valente , m. cozzolino fig . 9 – percentage of archaeological si
# y respect to the total mapped sites . fig . 8 – box plot of the site elevation
#  it is worthy to note that , anyway , fig . 10 – a ) white dots indicate archae
#
#
# Concordance for 'age':
# Displaying 35 of 35 matches:
#  chronologically dated to the samnite age ( ranging from the v to the i century
#  the samnites ’ culture . the samnite age ceased with the arrive of the romans
# also noteworthy evidences of medieval age , whose stories and transformations r
# 1 ( string , length 254 ) , a precise age of every site ; – age_2 ( string , le
# length 254 ) , ages grouped in the 11 age ranges proposed by barker ( 1995 ) :
# eolithic ( 3000 bc-2000 bc ) , bronze age ( 2000 bc-1000 bc ) , iron age ( 1000
# bronze age ( 2000 bc-1000 bc ) , iron age ( 1000 bc-500 bc ) , samnite age ( 50
# iron age ( 1000 bc-500 bc ) , samnite age ( 500 bc-80 bc ) , roman age ( 80 bc-
#  samnite age ( 500 bc-80 bc ) , roman age ( 80 bc-600 bc ) , medieval age ( 600
# roman age ( 80 bc-600 bc ) , medieval age ( 600 ad-1500 ad ) , post-medieval ag
# ge ( 600 ad-1500 ad ) , post-medieval age ( 1500 ad-1800 ad ) , recent age ( 18
# eval age ( 1500 ad-1800 ad ) , recent age ( 1800 ad-present ) . 372 e. valente
# g all the archaeological sites in the age classes listed in the age_2 field of
# le . archaeological sites grouped for age have been then plotted on the 40 m mo
# rs above sea level ) respect the site age has been examined to verify a possibl
# ll archaeological sites with the same age and exported them in a new point shap
#  eneolithic ( fig . 7c ) , the bronze age ( fig . 7d ) and the iron age ( fig .
#  bronze age ( fig . 7d ) and the iron age ( fig . 7e ) , archaeological sites h
# tor of the study area during the iron age . archaeological sites of samnite age
# age . archaeological sites of samnite age ( fig . 7f ) are widespread all over
#  total , fig . 7k ) have an uncertain age and they have been mainly recognized
# tes archaeological sites of a precise age whereas black dots indicate archaeolo
# gical sites older than the considered age . we have also analysed site distribu
# e elevation as a function of the site age . it is possible to note that the min
# a local minimum during the eneolithic age ( median value around 190 m a.s.l. )
#  1300 m a.s.l . ( during the medieval age ) , with a local minimum during the e
# a local minimum during the eneolithic age ( maximum elevation around 880 m a.s.
# nd a local maximum during the samnite age ( maximum elevation close to 1400 m a
# tes from the palaeolithic to the iron age have been excluded from this analysis
# s ( 19 % of the 2786 sites ranging in age from the samnite to the recent time )
# , also counting 58 sites of uncertain age . all the site typologies listed in f
#  also including 45 sites of uncertain age . again , all the site typologies lis
# n ( m a.s.l . ) as a function of site age . moreover , this study provides a po
# , during the palaeolithic to the iron age time span , archaeological sites were
#  this period , and during the samnite age , humans started moving uphill , as i
#
#
# Concordance for '–':
# Displaying 32 of 32 matches:
#  according to the following workflow : – census of all known archaeological fin
# egion through bibliographic analysis . – implementation , for the first time ,
#  and updated archaeological database . – integration of this database into a ge
# in the molise region ( italy ) fig . 1 – some of the most relevant archaeologic
# onastery of san vincenzo al volturno . – generation of an updated computerized
# ows ( field type is in parentheses ) : – code ( string , length 10 ) that inclu
# ted followed by a progressive number ; – province ( string , length 20 ) , whic
# ere archaeological sites fall within ; – municipality ( string , length 50 ) ,
# nicipality where the site is located ; – locality ( string , length 50 ) and ad
# ther information about site location ; – reference system ( string , length 20
# e archaeological sites ( utm-wgs84 ) ; – z coord ( double , precision 0 , scale
# vation above sea level of every site ; – point x ( double , precision 0 , scale
# de of the plotted sites respectively ; – cartography ( string , length 20 ) tha
# or 1:25.000 scale topographic maps ) ; – number cart . ( string , length 20 ) t
# e number of the used topographic map ; – georeferencing method ( string , lengt
# c maps , field work or aerial photos ; – georeference quality ( string , length
# w much reliable the site location is ; – research method ( string , length 50 )
# ibliographic research and field work ; – description ( string , length 254 ) ,
# h have been subdivided in 19 classes ; – definition ( string , length 254 ) a b
# re detailed description of the sites ; – description_1 to description_5 ( strin
# ription of every archaeological site ; – age_1 ( string , length 254 ) , a prec
#  254 ) , a precise age of every site ; – age_2 ( string , length 254 ) , ages g
# sent ) . 372 e. valente , m. cozzolino – references ( string , length 254 ) , b
#  only 6 archaeological sites . fig . 2 – spatial distribution of the mapped arc
#  374 e. valente , m. cozzolino fig . 3 – map of the archaeological sites for al
# in the molise region ( italy ) fig . 4 – map of the archaeological sites for al
#  376 e. valente , m. cozzolino fig . 5 – map of the archaeological sites for al
# in the molise region ( italy ) fig . 6 – density map of the archaeological site
#  378 e. valente , m. cozzolino fig . 7 – chronological distribution of the arch
#  380 e. valente , m. cozzolino fig . 9 – percentage of archaeological site typo
# ct to the total mapped sites . fig . 8 – box plot of the site elevation ( m a.s
# orthy to note that , anyway , fig . 10 – a ) white dots indicate archaeological
#
#
# Concordance for 'del':
# Displaying 31 of 31 matches:
# no ( grotta reali site ) , civitanova del sannio ( morricone del pesco site ) ,
# ) , civitanova del sannio ( morricone del pesco site ) , cerro al volturno ( mo
#  , bonefro , casacalenda , castellino del biferno , colletorto , montelongo , m
# ngo , montorio dei frentani , morrone del sannio , provvidenti , ripabottoni ,
# 015 ; amato et al . 2016 ) , belmonte del sannio , agnone , capracotta , vastog
# cipality of castropignano and torella del sannio to the n and of bojano , san p
#  , vinchiaturo ( 44 sites ) , morrone del sannio ( 43 sites ) , san martino in
# sociali e della formazione università del molise marilena.cozzolino @ unimol.it
#  rotili ( eds . ) , la trasformazione del mondo romano e le grandi migrazioni .
# rionale e centro-orientale alle coste del mediterraneo . atti del convegno inte
# le alle coste del mediterraneo . atti del convegno internazionale di studi ( ci
# enti alle antichità e alle belle arti del molise , 5 , campobasso , 16-17. de b
# ituto regionale per gli studi storici del molise . de tata p. 1990 , l ’ anfite
# iro ( eds . ) , samnium . archeologia del molise , catalogo della mostra , roma
#  santone m. , santoro w. 2010 , carta del rischio archeologico nell ’ area del
#  del rischio archeologico nell ’ area del cratere . primi dati di survey nei co
# i survey nei comuni colpiti dal sisma del 2002 , campobasso , soprintendenza pe
# oprintendenza per i beni archeologici del molise . di rocco g. 2009 , castelli
# edievale 10 , firenze , all ’ insegna del giglio . djindjian f. 1998 , gis usag
# 2005 , nuove ricerche sul paleolitico del molise . materie prime , industrie li
# ante e il sannio antico , « almanacco del molise » , 161-208. lippolis e. , gui
#  2015 , larino : ricerche nell ’ area del foro , « scienze dell ’ antichità » ,
#  , pesino c. 2003 , guida ai castelli del molise , pescara , carsa edizioni . m
# contri e suggestioni lungo i tratturi del molise , cerro al volturno , volturni
# eistoria in molise . gli insediamenti del territorio di isernia , roma , aracne
# frentani dal vi al i secolo a.c. atti del convegno ( isernia 1980 ) , campobass
# 007 , geografia e storia dei tratturi del mezzogiorno , roma , aracne . peretto
# te sulla preistoria dell ’ alta valle del volturno , in a. testa ( ed . ) , l ’
# azia di san vincenzo e l ’ alta valle del volturno , « archeomolise » , 3 , 8 ,
# ta archeologica dei territori montani del sannio pentro nord-occidentale , tesi
# 0 , atlante delle emergenze culturali del molise . risultati , riflessioni ed i

# %% [markdown]
# ## end of nltk##
#
# ##Time for pandas

# %%
import pandas as pd

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')

pd.options.display.max_rows = 100
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
litrev_df = pd.read_csv('chatgptgabii.csv', delimiter=",")



litrev_df
# Out:
#     Primary_Name          X          Y    Z Geog_certainty Occ_Date_U  \
# 0        Abella   14.608472  40.961516  236        certain       -800
# 1      Abellinum  14.830911  40.922125  313        certain       -300
# 2        Acerrae  14.371233  40.946092   30        certain       -300
# 3     Aceruntia   15.940567  40.796975  833        certain       -600
# 4          Aecae  15.308894  41.361189  439        certain       -600
# ..           ...        ...        ...  ...            ...        ...
# 352    Visentium  11.874036  42.573358  397        certain       -400
# 353       Volcei  15.379029  40.633914  663        certain       -325
# 354     Volsinii  11.986114  42.644852  522        certain       -250
# 355    Volturnum  13.941734  41.033657    2        certain       -194
# 356        Vulci  11.628128  42.419129   75        certain       -950
#
#     Occ_Date_L Occ_Date_Cert
# 0          500          High
# 1          500        Medium
# 2          500        Medium
# 3          500           Low
# 4          500        Medium
# ..         ...           ...
# 352        500           Low
# 353        500          High
# 354        500          High
# 355        500        Medium
# 356        500          High
#
# [357 rows x 8 columns]

# %%
# Check the first few rows of the DataFrame
print(litrev_df.head())

litrev_df = litrev_df[litrev_df["Primary_Name"].notna()]

abstracts_as_text = ""

for i in litrev_df["Primary_Name"]:
    abstracts_as_text += i + "\n"    
    
abstractTokens = word_tokenize(abstracts_as_text.lower())

cleaned_abstractTokens = []

for word in list(abstractTokens):
    if word not in stopwords.words("english") and word.isalpha():
        cleaned_abstractTokens.append(word)

abstracts_df = pd.DataFrame(cleaned_abstractTokens, columns =['uniqueWords'])
        
keywords = abstracts_df["uniqueWords"].value_counts()

if 100000000000 < len(keywords):
    specific_keyword = keywords.iloc[100000000000]
    print("Specific keyword:", specific_keyword)
else:
    print("Index is out of bounds.")

keywords[10]

print(keywords)
# Out:
#   Primary_Name          X          Y    Z Geog_certainty Occ_Date_U  \
# 0      Abella   14.608472  40.961516  236        certain       -800
# 1    Abellinum  14.830911  40.922125  313        certain       -300
# 2      Acerrae  14.371233  40.946092   30        certain       -300
# 3   Aceruntia   15.940567  40.796975  833        certain       -600
# 4        Aecae  15.308894  41.361189  439        certain       -600
#
#   Occ_Date_L Occ_Date_Cert
# 0        500          High
# 1        500        Medium
# 2        500        Medium
# 3        500           Low
# 4        500        Medium
# Index is out of bounds.
# uniqueWords
# monte        39
# san          14
# di           13
# colle        13
# santa         8
#              ..
# croccia       1
# presepe       1
# cozzo         1
# corfinium     1
# vulci         1
# Name: count, Length: 386, dtype: int64
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6604\648131959.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   keywords[10]
